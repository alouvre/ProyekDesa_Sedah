# %% [markdown]
# <a href="https://colab.research.google.com/github/alouvre/ProyekDesa_Sedah/blob/main/ProyekDesa_SensusDesaSedah.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/alouvre/ProyekDesa_Sedah.git

# %%
import pandas as pd

# %% [markdown]
# # **COLLECTING DATA**

# %% [markdown]
# ## DUSUN KRAJAN - REVISI

# %% [markdown]
# ### RT01 - DROP 54-61

# %%
KrajanRT01 = pd.read_excel('ProyekDesa_Sedah/RekapSurveySensusDesaSedah/K20_KRAJAN/DATA PENDUDUK DUSUN SIDOREJO RT 01^J 02^J 03 KRAJAN RT 1,RT 2, RT 3 FIXX.xlsx', sheet_name='RT 1')
KrajanRT01 = KrajanRT01.iloc[5:]
KrajanRT01 = KrajanRT01.drop(KrajanRT01.columns[0], axis=1)
KrajanRT01.head(1)
# Out:
#   Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4     Unnamed: 5 Unnamed: 6  \
# 5  ALI IMRON        NaN     TUKANG        SMA  SITI ANJARIAH        NaN
#
#   Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10  ... Unnamed: 29 Unnamed: 30  \
# 5       GURU         S1        NaN         NaN  ...         NaN         NaN
#
#   Unnamed: 31 Unnamed: 32 Unnamed: 33 Unnamed: 34 Unnamed: 35 Unnamed: 36  \
# 5         NaN           √         NaN         NaN         NaN         NaN
#
#   Unnamed: 37 Unnamed: 38
# 5         NaN    MENENGAH
#
# [1 rows x 38 columns]

# %%
KrajanRT01.columns = ['Nama_Ayah', 'TTL_Ayah', 'Pekerjaan_Ayah', 'Pendidikan_Ayah',
                    'Nama_Ibu', 'TTL_Ibu', 'Pekerjaan_Ibu', 'Pendidikan_Ibu',
                    'Nama_Anak1', 'TTL_Anak1', 'Pekerjaan_Anak1', 'Pendidikan_Anak1',
                    'Nama_Anak2', 'TTL_Anak2', 'Pekerjaan_Anak2', 'Pendidikan_Anak2',
                    'Nama_Anak3', 'TTL_Anak3', 'Pekerjaan_Anak3', 'Pendidikan_Anak3',
                    'Nama_Anak4', 'TTL_Anak4', 'Pekerjaan_Anak4', 'Pendidikan_Anak4',
                    'RT_MilikSendiri', 'RT_IkutOrangTua', 'RT_Kontrak',
                    'Tanah_Sawah', 'Tanah_Kebun',
                    'HT_Sapi', 'HT_Kambing', 'HT_Ayam', 'HT_Bebek', 'HT_Lele',
                    'K_Mobil', 'K_Motor', 'Lainnya', 'Kategori'
                    ]

# %%
KrajanRT01.head(57)
# DROP INDEKS 54-61
# Out:
#                   Nama_Ayah       TTL_Ayah       Pekerjaan_Ayah  \
# 5                 ALI IMRON            NaN               TUKANG
# 6                   SUMANTO            NaN           BURUH TANI
# 7         ARIF WAHYU WIDODO            NaN  PEGAWAI RUMAH SAKIT
# 8                   KADIMUN            NaN               TUKANG
# 9                     SAKRI            NaN               PETANI
# 10                  MULYOTO            NaN           BURUH TANI
# 11                      NaN            NaN                  NaN
# 12                  SUKARNO            NaN           BURUH TANI
# 13                   KUSNAN            NaN           KONTRAKTOR
# 14      ARIZKY RAGIL ANDYKA            NaN            PENGUSAHA
# 15                      NaN            NaN                  NaN
# 16                  KATIMUN            NaN               PETANI
# 17               BASHIRUDIN            NaN               TUKANG
# 18                  PURNOMO            NaN               TUKANG
# 19               SUPRIYANTO            NaN             KARYAWAN
# 20               USMAN HADI            NaN               PETANI
# 21           HERU NOVIYANTO            NaN               PETANI
# 22                   JIKUN             NaN               PETANI
# 23                      NaN            NaN                  NaN
# 24             JOKO SUYITNO            NaN               TUKANG
# 25                  SARJUNI            NaN               PETANI
# 26         RYHAN WARA ADI K            NaN              PELAJAR
# 27                   SUYADI            NaN               PETANI
# 28             ARJO MESERAN            NaN               PETANI
# 29                   SUYOTO            NaN             PEDAGANG
# 30                   SUMALI            NaN               PETANI
# 31               TRI ATMONO            NaN              PETANI
# 32                    SARNI            NaN           BURUH TANI
# 33                    SARDO            NaN               PETANI
# 34                      NaN            NaN                  NaN
# 35          ANANG FADHILAH             NaN               POLISI
# 36                   SUYONO            NaN               PETANI
# 37                  NAHROWI            NaN               PETANI
# 38                   SUTAJI            NaN               PETANI
# 39                  SUWANDI            NaN               PETANI
# 40                  SUNARNI            NaN                 GURU
# 41                      NaN            NaN                  NaN
# 42          BANDUNG RURANTO            NaN           BURUH TANI
# 43           DIDIK ZULIANTO            NaN                 GURU
# 44                      NaN            NaN                  NaN
# 45                  SUGIONO            NaN                  PNS
# 46                      NaN            NaN                  NaN
# 47              EDI NUGROHO            NaN           WIRASWASTA
# 48           MUHAMMAD SIDIQ            NaN               PETANI
# 49             IMAM MUSTOFA            NaN               PETANI
# 50                      NaN            NaN                  NaN
# 51                      NaN            NaN                  NaN
# 52             HERI ERWANTO            NaN                  ASN
# 53  ADITIYA SYAFI'I ZUBAINI            NaN            PENGUSAHA
# 54                      NaN            NaN                  NaN
# 55                      NaN            NaN                  NaN
# 56                      NaN            NaN                  NaN
# 57                      NaN            NaN                  NaN
# 58                      NaN            NaN                  NaN
# 59                      NaN  PRA SEJAHTERA                    0
# 60                      NaN       MENENGAH                   34
# 61                      NaN      SEJAHTERA                    5
#
#      Pendidikan_Ayah            Nama_Ibu TTL_Ibu Pekerjaan_Ibu  \
# 5                SMA       SITI ANJARIAH     NaN          GURU
# 6                SMP         SITI ZAINAB     NaN           NaN
# 7                SMA      RULI WIDYAWATI     NaN           NaN
# 8                SMA                 NaN     NaN           NaN
# 9                 SD             SUYATMI     NaN           NaN
# 10                SD             SUSANNA     NaN           NaN
# 11               NaN             MESIJAH     NaN     IBU RUMAH
# 12                SD                 NaN     NaN           NaN
# 13                SD      WIWIK REDANING     NaN           NaN
# 14              SLTA    AFRISNA MASDIANA     NaN           NaN
# 15               NaN              KAYATI     NaN     IBU RUMAH
# 16                SD             TUKINEM     NaN           NaN
# 17              SLTA             SUNARTI     NaN           NaN
# 18              SLTP            DINIYATI     NaN           NaN
# 19                SD                 NaN     NaN           NaN
# 20              SLTP           MISTRIANI     NaN           NaN
# 21              SLTA        NIA ARMAWATI     NaN           NaN
# 22               NaN              SUYATI     NaN           NaN
# 23               NaN             SUTIRAH     NaN     IBU RUMAH
# 24                SD            MARMIATI     NaN           NaN
# 25                SD             MINATUN     NaN           NaN
# 26                SD                 NaN     NaN           NaN
# 27              SLTP        SITI MARYUNI     NaN           NaN
# 28                SD             SUPIYAH     NaN           NaN
# 29              SLTP        SITI RUKANAH     NaN           NaN
# 30                SD        SITI MARHENI     NaN           NaN
# 31               SMP          UMI SAUDAH     NaN           NaN
# 32               NaN             SUNDARI     NaN           NaN
# 33                SD                 NaN     NaN           NaN
# 34               NaN          WAKHIDATUL     NaN     IBU RUMAH
# 35  S1 SARJANA HUKUM        YENI MARLINA     NaN           NaN
# 36                SD             PONIRAH     NaN           NaN
# 37                SD        SITI SAMANAH     NaN           NaN
# 38              SLTA             HARYUNI     NaN           NaN
# 39               SMP   ENDANG SUSILOWATI     NaN           NaN
# 40               S1                  NaN     NaN           NaN
# 41               NaN      BINTI KHORIYAH     NaN        PETANI
# 42              SLTA    TRI ARYA YULIANA     NaN           NaN
# 43              SLTA                 NaN     NaN           NaN
# 44               NaN      DARNING TUTIEK     NaN           IRT
# 45                S1    IQLIMA  HERAWATY     NaN           NaN
# 46                 -      NANIK ISMIYATI     NaN    BURUH TANI
# 47              SLTA    FITRI NURMASANTI     NaN           IRT
# 48                SD        PUPUT RAHAYU     NaN           NaN
# 49                S1        IRAMAYA SARI     NaN        PETANI
# 50               NaN             SUKILAH     NaN           IRT
# 51               NaN              SIYEM      NaN           IRT
# 52                S1           RATNAWATI     NaN           ASN
# 53                S1  FARICHA NUR RAHMAH     NaN           NaN
# 54               NaN                 NaN     NaN           NaN
# 55               NaN                 NaN     NaN           NaN
# 56               NaN                 NaN     NaN           NaN
# 57               NaN                 NaN     NaN           NaN
# 58               NaN                 NaN     NaN           NaN
# 59               NaN                 NaN     NaN           NaN
# 60               NaN                 NaN     NaN           NaN
# 61               NaN                 NaN     NaN           NaN
#
#         Pendidikan_Ibu                  Nama_Anak1 TTL_Anak1  ... Tanah_Kebun  \
# 5                   S1                         NaN       NaN  ...         NaN
# 6                  SMA             APRILIA SAMANTA       NaN  ...         NaN
# 7                   S1               RAFIF WAHYU A       NaN  ...         NaN
# 8                  NaN                         NaN       NaN  ...         NaN
# 9                   SD                         NaN       NaN  ...         NaN
# 10                  SD                         NaN       NaN  ...         NaN
# 11                 NaN                         NaN       NaN  ...         NaN
# 12                 NaN                         NaN       NaN  ...         NaN
# 13                  SD          FARENDRA MASDILANA       NaN  ...         NaN
# 14            S1 HUKUM       AZIA KINARA CAKRAWALA       NaN  ...         NaN
# 15                 NaN                         NaN       NaN  ...         NaN
# 16                  SD                         NaN       NaN  ...         NaN
# 17                SLTA                 SALMA AZURA       NaN  ...         NaN
# 18                  SD   NENI AFRILIA PRASTISTIANA       NaN  ...         NaN
# 19                 NaN                         NaN       NaN  ...         NaN
# 20                SLTP          MOHAMAD FERDI AZIZ       NaN  ...           √
# 21                SLTA          ALMEER IZHAR MAUZA       NaN  ...         NaN
# 22                  SD                         NaN       NaN  ...         NaN
# 23                  SD                         NaN       NaN  ...           √
# 24                SLTP            CHAVIN MAYOCHI N       NaN  ...         NaN
# 25                 NaN                         NaN       NaN  ...         NaN
# 26                 NaN                         NaN       NaN  ...         NaN
# 27             PAKET C                         NaN       NaN  ...         NaN
# 28                  SD                         NaN       NaN  ...         NaN
# 29                SLTA      DANANG LUKMANUL KHAKIM       NaN  ...         NaN
# 30                  SD                         NaN       NaN  ...         NaN
# 31                 SMP           ATTA TSANI ULAYYA       NaN  ...         NaN
# 32                 NaN                         NaN       NaN  ...         NaN
# 33                 NaN                         NaN       NaN  ...         NaN
# 34                SLTP         IBRAHIM ZAIN ELFAIQ       NaN  ...         NaN
# 35  S1 SARJANA PERHUTA      BENING BIDARI FADHILAH       NaN  ...         NaN
# 36                  SD         ANGGITA ARA SABILLA       NaN  ...         NaN
# 37                SLTP          ROSA IKA OCTARIANI       NaN  ...         NaN
# 38                SLTA    MUHAMMAD FARREL AL FAUZI       NaN  ...         NaN
# 39                 SMP        JOEY YOGI NUR ANGELY       NaN  ...         NaN
# 40                 NaN                         NaN       NaN  ...         NaN
# 41                 SMP           NAFIATU ROHMAWATI       NaN  ...         NaN
# 42                SLTP          LEANDARA ASHABRYNA       NaN  ...         NaN
# 43                SLTA                         NaN       NaN  ...         NaN
# 44                SLTA                 ANISA PUTRI       NaN  ...         NaN
# 45                  S1          AYLA SYAFANA ARBAH       NaN  ...         NaN
# 46                   -                         NaN       NaN  ...         NaN
# 47                 SMP         HAFIS RIZKI NUGROHO       NaN  ...         NaN
# 48                SMP\         ERLIYA NANTA RAHAYU       NaN  ...         NaN
# 49                  S1     REFA ANINDHITA AZ-ZAHRA       NaN  ...         NaN
# 50                   -                         NaN       NaN  ...         NaN
# 51                   -                         NaN       NaN  ...         NaN
# 52                  S1       GARZEKYALTAN  DESTERA       NaN  ...         NaN
# 53                  S1  ANINDIRA SHAUQEENA QIANDRA       NaN  ...         NaN
# 54                                             NaN       NaN  ...         NaN
# 55                 NaN                         NaN       NaN  ...         NaN
# 56                 NaN                         NaN       NaN  ...         NaN
# 57                 NaN                         NaN       NaN  ...         NaN
# 58                 NaN                         NaN       NaN  ...         NaN
# 59                 NaN                         NaN       NaN  ...         NaN
# 60                 NaN                         NaN       NaN  ...         NaN
# 61                 NaN                         NaN       NaN  ...         NaN
#
#    HT_Sapi HT_Kambing HT_Ayam HT_Bebek HT_Lele K_Mobil K_Motor Lainnya  \
# 5      NaN        NaN       √      NaN     NaN     NaN     NaN     NaN
# 6      NaN        NaN     NaN      NaN     NaN     NaN     NaN     NaN
# 7      NaN        NaN       √      NaN     NaN     NaN     NaN     NaN
# 8      NaN        NaN       √      NaN     NaN     NaN     NaN     NaN
# 9      NaN          √       √      NaN     NaN     NaN     NaN     NaN
# 10     NaN          √       √      NaN     NaN     NaN     NaN     NaN
# 11     NaN        NaN     NaN      NaN     NaN     NaN     NaN     NaN
# 12     NaN        NaN       √      NaN     NaN     NaN     NaN     NaN
# 13     NaN        NaN     NaN      NaN     NaN       v     NaN     NaN
# 14     NaN        NaN     NaN      NaN     NaN     NaN     NaN     NaN
# 15     NaN        NaN       √      NaN     NaN     NaN     NaN     NaN
# 16     NaN          √       √      NaN     NaN     NaN     NaN     NaN
# 17     NaN        NaN     NaN      NaN     NaN     NaN     NaN     NaN
# 18     NaN        NaN       √      NaN     NaN     NaN     NaN     NaN
# 19     NaN        NaN     NaN      NaN     NaN     NaN     NaN     NaN
# 20     NaN          √       √      NaN     NaN     NaN     NaN     NaN
# 21     NaN        NaN     NaN      NaN     NaN     NaN     NaN     NaN
# 22     NaN        NaN       √      NaN     NaN     NaN     NaN     NaN
# 23     NaN          √       √      NaN     NaN     NaN     NaN     NaN
# 24     NaN        NaN     NaN      NaN     NaN     NaN     NaN     NaN
# 25       √        NaN       √      NaN     NaN     NaN     NaN     NaN
# 26     NaN        NaN     NaN      NaN     NaN     NaN     NaN     NaN
# 27     NaN        NaN       √      NaN     NaN     NaN     NaN     NaN
# 28     NaN        NaN     NaN      NaN     NaN     NaN     NaN     NaN
# 29     NaN        NaN     NaN      NaN     NaN     NaN     NaN     NaN
# 30     NaN          √     NaN      NaN     NaN     NaN     NaN     NaN
# 31     NaN          √     NaN      NaN     NaN     NaN     NaN     NaN
# 32     NaN          √     NaN      NaN     NaN     NaN     NaN     NaN
# 33       √        NaN     NaN      NaN     NaN     NaN     NaN     NaN
# 34     NaN        NaN     NaN      NaN     NaN     NaN     NaN     NaN
# 35     NaN        NaN     NaN      NaN     NaN     NaN     NaN     NaN
# 36     NaN          √       √      NaN     NaN     NaN     NaN     NaN
# 37     NaN        NaN       √      NaN     NaN     NaN     NaN     NaN
# 38     NaN          √       √      NaN     NaN     NaN     NaN     NaN
# 39     NaN          √       √      NaN     NaN     NaN     NaN     NaN
# 40     NaN        NaN     NaN      NaN     NaN     NaN     NaN     NaN
# 41     NaN          √       √      NaN     NaN     NaN     NaN     NaN
# 42     NaN          √       √      NaN     NaN     NaN     NaN     NaN
# 43     NaN        NaN     NaN      NaN     NaN     NaN     NaN     NaN
# 44     NaN        NaN     NaN      NaN     NaN     NaN     NaN     NaN
# 45     NaN        NaN       √      NaN     NaN     NaN     NaN     NaN
# 46     NaN        NaN     NaN      NaN     NaN     NaN     NaN     NaN
# 47     NaN        NaN     NaN      NaN     NaN     NaN     NaN     NaN
# 48     NaN          √       √      NaN     NaN     NaN     NaN     NaN
# 49     NaN        NaN     NaN      NaN     NaN     NaN     NaN     NaN
# 50     NaN        NaN     NaN      NaN     NaN     NaN     NaN     NaN
# 51     NaN        NaN     NaN      NaN     NaN     NaN     NaN     NaN
# 52     NaN          √     NaN      NaN     NaN     NaN     NaN     NaN
# 53     NaN        NaN     NaN      NaN     NaN     NaN     NaN     NaN
# 54     NaN        NaN     NaN      NaN     NaN     NaN     NaN     NaN
# 55     NaN        NaN     NaN      NaN     NaN     NaN     NaN     NaN
# 56     NaN        NaN     NaN      NaN     NaN     NaN     NaN     NaN
# 57     NaN        NaN     NaN      NaN     NaN     NaN     NaN     NaN
# 58     NaN        NaN     NaN      NaN     NaN     NaN     NaN     NaN
# 59     NaN        NaN     NaN      NaN     NaN     NaN     NaN     NaN
# 60     NaN        NaN     NaN      NaN     NaN     NaN     NaN     NaN
# 61     NaN        NaN     NaN      NaN     NaN     NaN     NaN     NaN
#
#      Kategori
# 5    MENENGAH
# 6    MENENGAH
# 7    MENENGAH
# 8    MENENGAH
# 9    MENENGAH
# 10   MENENGAH
# 11   MENENGAH
# 12   MENENGAH
# 13  SEJAHTERA
# 14  SEJAHTERA
# 15   MENENGAH
# 16   MENENGAH
# 17   MENENGAH
# 18   MENENGAH
# 19   MENENGAH
# 20   MENENGAH
# 21   MENENGAH
# 22   MENENGAH
# 23   MENENGAH
# 24   MENENGAH
# 25   MENENGAH
# 26   MENENGAH
# 27   MENENGAH
# 28   MENENGAH
# 29   MENENGAH
# 30   MENENGAH
# 31   MENENGAH
# 32   MENENGAH
# 33   MENENGAH
# 34   MENENGAH
# 35  SEJAHTERA
# 36   MENENGAH
# 37   MENENGAH
# 38   MENENGAH
# 39   MENENGAH
# 40   MENENGAH
# 41   MENENGAH
# 42   MENENGAH
# 43   MENENGAH
# 44   MENENGAH
# 45  SEJAHTERA
# 46   MENENGAH
# 47   MENENGAH
# 48   MENENGAH
# 49   MENENGAH
# 50   MENENGAH
# 51   MENENGAH
# 52  SEJAHTERA
# 53   MENENGAH
# 54        NaN
# 55        NaN
# 56        NaN
# 57        NaN
# 58        NaN
# 59        NaN
# 60        NaN
# 61        NaN
#
# [57 rows x 38 columns]

# %%
KrajanRT01.shape
# Out:
# (57, 38)

# %% [markdown]
# ### RT02 - DROP 36-59

# %%
KrajanRT02 = pd.read_excel('ProyekDesa_Sedah/RekapSurveySensusDesaSedah/K20_KRAJAN/DATA PENDUDUK DUSUN SIDOREJO RT 01^J 02^J 03 KRAJAN RT 1,RT 2, RT 3 FIXX.xlsx', sheet_name='RT 2')
KrajanRT02 = KrajanRT02.iloc[5:]
KrajanRT02 = KrajanRT02.drop(KrajanRT02.columns[0], axis=1)
KrajanRT02.head(1)
# Out:
#       Unnamed: 1 Unnamed: 2   Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 5  LUKMAN EFENDI        NaN  KEPALA DESA       S1          NaN        NaN
#
#   Unnamed: 7 Unnamed: 8       Unnamed: 9 Unnamed: 10  ... Unnamed: 29  \
# 5        NaN        NaN  MUHAMMAD  HARIR         NaN  ...         NaN
#
#   Unnamed: 30 Unnamed: 31 Unnamed: 32 Unnamed: 33 Unnamed: 34 Unnamed: 35  \
# 5         NaN         NaN           √         NaN         NaN         NaN
#
#   Unnamed: 36 Unnamed: 37 Unnamed: 38
# 5         NaN         NaN   SEJAHTERA
#
# [1 rows x 38 columns]

# %%
KrajanRT02.columns = ['Nama_Ayah', 'TTL_Ayah', 'Pekerjaan_Ayah', 'Pendidikan_Ayah',
                    'Nama_Ibu', 'TTL_Ibu', 'Pekerjaan_Ibu', 'Pendidikan_Ibu',
                    'Nama_Anak1', 'TTL_Anak1', 'Pekerjaan_Anak1', 'Pendidikan_Anak1',
                    'Nama_Anak2', 'TTL_Anak2', 'Pekerjaan_Anak2', 'Pendidikan_Anak2',
                    'Nama_Anak3', 'TTL_Anak3', 'Pekerjaan_Anak3', 'Pendidikan_Anak3',
                    'Nama_Anak4', 'TTL_Anak4', 'Pekerjaan_Anak4', 'Pendidikan_Anak4',
                    'RT_MilikSendiri', 'RT_IkutOrangTua', 'RT_Kontrak',
                    'Tanah_Sawah', 'Tanah_Kebun',
                    'HT_Sapi', 'HT_Kambing', 'HT_Ayam', 'HT_Bebek', 'HT_Lele',
                    'K_Mobil', 'K_Motor', 'Lainnya', 'Kategori'
                    ]

# %%
KrajanRT02.head(55)
# DROP INDEKS 36-59
# Out:
#           Nama_Ayah       TTL_Ayah Pekerjaan_Ayah Pendidikan_Ayah  \
# 5     LUKMAN EFENDI            NaN    KEPALA DESA            S1
# 6               NaN            NaN            NaN             NaN
# 7      JOKO PURNOMO            NaN         PETANI            SLTA
# 8            CHABIB            NaN         SWASTA            S1
# 9          ZAINURI             NaN            PNS            S1
# 10              NaN            NaN            NaN             NaN
# 11           SAKUR             NaN            NaN            SLTA
# 12       SYAFRUDDIN            NaN            PNS            S1
# 13   G. TRI WAHYONO            NaN          BPBD             S1
# 14        SUGIYANTO            NaN   BURUH PABRIK              SD
# 15              NaN            NaN            NaN             NaN
# 16     AHMAD KENIDI            NaN     WIRASWASTA             SMA
# 17              NaN            NaN            NaN             NaN
# 18              NaN            NaN            NaN             NaN
# 19     ACHMAD RIJAL            NaN     WIRASWASTA            S1
# 20    SLAMET RIYADI            NaN       PEDAGANG             SMK
# 21              NaN            NaN            NaN             NaN
# 22          SUMANTO            NaN     BURUH TANI            SLTP
# 23            SENUN            NaN         PETANI              SD
# 24                             NaN            NaN             NaN
# 25        MASHUDI              NaN     BURUH TANI            SLTA
# 26              NaN            NaN            NaN             NaN
# 27              NaN            NaN            NaN             NaN
# 28   BARUDIN RIFAI             NaN         PETANI            SLTA
# 29           MAHSUN            NaN         PETANI             SMP
# 30       SYAMSYUDIN            NaN     BURUH TANI             SMP
# 31              NaN            NaN            NaN             NaN
# 32              NaN            NaN            NaN             NaN
# 33      MUKRI YAHYA            NaN              -            SLTA
# 34        SAMSUDIN             NaN     BURUH TANI             SMP
# 35  MAHFUD ABDULLAH            NaN      WIRAUSAHA             SMA
# 36              NaN            NaN            NaN             NaN
# 37              NaN            NaN            NaN             NaN
# 38              NaN            NaN            NaN             NaN
# 39              NaN            NaN            NaN             NaN
# 40              NaN            NaN            NaN             NaN
# 41              NaN            NaN            NaN             NaN
# 42              NaN            NaN            NaN             NaN
# 43              NaN            NaN            NaN             NaN
# 44              NaN            NaN            NaN             NaN
# 45              NaN            NaN            NaN             NaN
# 46              NaN            NaN            NaN             NaN
# 47              NaN            NaN            NaN             NaN
# 48              NaN            NaN            NaN             NaN
# 49              NaN            NaN            NaN             NaN
# 50              NaN            NaN            NaN             NaN
# 51              NaN  PRA SEJAHTERA              2             NaN
# 52              NaN       MENENGAH             19             NaN
# 53              NaN      SEJAHTERA             10             NaN
# 54              NaN            NaN            NaN             NaN
# 55              NaN            NaN            NaN             NaN
# 56              NaN            NaN            NaN             NaN
# 57              NaN            NaN            NaN             NaN
# 58              NaN            NaN            NaN             NaN
# 59              NaN            NaN            NaN               \
#
#               Nama_Ibu TTL_Ibu Pekerjaan_Ibu Pendidikan_Ibu  \
# 5                  NaN     NaN           NaN            NaN
# 6            MUTMAINAH     NaN    WIRASWASTA            NaN
# 7       TITIK MAESAROH     NaN        PETANI           SLTA
# 8                 MIRA     NaN           IRT            SMP
# 9         SULIS ROFIAH     NaN           IRT           SLTA
# 10          HARTINAH       NaN    BURUH TANI             SD
# 11           MASRIFAH      NaN          IRT            SLTP
# 12        SUHARTINAH       NaN           NaN           SMA
# 13       DIAN KUSUMA       NaN           IRT             S1
# 14  IMROATUL KHASANAH      NaN           IRT           SLTA
# 15           NURHAYATI     NaN           IRT             SD
# 16                 NaN     NaN           NaN            NaN
# 17            SAMINEM      NaN       PETANI              SD
# 18           MUBAYANAH     NaN           IRT             SD
# 19        DINI SAFITRI     NaN    WIRASWASTA             S1
# 20           NURHAYATI     NaN           IRT           SMA
# 21             SUMARTI     NaN           IRT             SD
# 22                 NaN     NaN           NaN            NaN
# 23            MAS'AMAH     NaN        PETANI             SD
# 24             ENDANG      NaN          PNS              S1
# 25           SUPYATUN      NaN           IRT             SD
# 26       SITI MASRUROH     NaN   PENSIUN PNS           SMA
# 27       ENY ANALIYA       NaN    WIRASWASTA           SLTA
# 28        SITI MARFUAH     NaN           IRT           SLTP
# 29             SUNARTI     NaN        PETANI             SD
# 30        SITI FATIMAH     NaN    BURUH TANI            SMP
# 31           SRINGATUN     NaN           IRT             SD
# 32            SAMSIAH      NaN           IRT             SD
# 33                 NaN     NaN           NaN            NaN
# 34        SITI FATIMAH     NaN        PETANI           SMP'
# 35             KARYATI     NaN     WIRAUSAHA            SMA
# 36                 NaN     NaN           NaN            NaN
# 37                 NaN     NaN           NaN            NaN
# 38                 NaN     NaN           NaN            NaN
# 39                 NaN     NaN           NaN            NaN
# 40                 NaN     NaN           NaN            NaN
# 41                 NaN     NaN           NaN            NaN
# 42                 NaN     NaN           NaN            NaN
# 43                 NaN     NaN           NaN            NaN
# 44                 NaN     NaN           NaN            NaN
# 45                 NaN     NaN           NaN            NaN
# 46                 NaN     NaN           NaN            NaN
# 47                 NaN     NaN           NaN            NaN
# 48                 NaN     NaN           NaN            NaN
# 49                 NaN     NaN           NaN            NaN
# 50                 NaN     NaN           NaN            NaN
# 51                 NaN     NaN           NaN            NaN
# 52                 NaN     NaN           NaN            NaN
# 53                 NaN     NaN           NaN            NaN
# 54                 NaN     NaN           NaN            NaN
# 55                 NaN     NaN           NaN            NaN
# 56                 NaN     NaN           NaN            NaN
# 57                 NaN     NaN           NaN            NaN
# 58                 NaN     NaN           NaN            NaN
# 59                 NaN     NaN           NaN            NaN
#
#                    Nama_Anak1 TTL_Anak1  ... Tanah_Kebun HT_Sapi HT_Kambing  \
# 5             MUHAMMAD  HARIR       NaN  ...         NaN     NaN        NaN
# 6                         NaN       NaN  ...         NaN     NaN        NaN
# 7         HAJIS PRADANA PUTRA       NaN  ...         NaN     NaN        NaN
# 8            LAILY KURNIAWATI       NaN  ...         NaN     NaN        NaN
# 9                 AFID ARFANI       NaN  ...         NaN     NaN        NaN
# 10                        NaN       NaN  ...         NaN     NaN        NaN
# 11              FARID MASKURI       NaN  ...         NaN     NaN        NaN
# 12                        NaN       NaN  ...         NaN     NaN        NaN
# 13        FARAH AULIA AZZAHRA       NaN  ...         NaN     NaN        NaN
# 14   MUHAMMAD ASHABI MAULIDAN       NaN  ...         NaN     NaN        NaN
# 15                ALI  MUSAFA       NaN  ...         NaN     NaN        NaN
# 16  KEYSHA JAUZA NASWA KENIDI       NaN  ...         NaN     NaN        NaN
# 17                      MISNU       NaN  ...         NaN     NaN        NaN
# 18                        NaN       NaN  ...         NaN     NaN        NaN
# 19                   DEVANDRA       NaN  ...         NaN     NaN        NaN
# 20              DINI SAFITRI        NaN  ...         NaN     NaN        NaN
# 21                    SUMANTO       NaN  ...         NaN     NaN        NaN
# 22    DWI  YUSTIKA MAYSAPUTRI       NaN  ...         NaN     NaN        NaN
# 23       GALVA SHOFUAH RIFINA       NaN  ...         NaN     NaN        NaN
# 24                  REKIYANA        NaN  ...         NaN     NaN        NaN
# 25                 WAHYU MEI        NaN  ...         NaN     NaN        NaN
# 26      NELVANA  DWI CAHYANTI       NaN  ...         NaN     NaN        NaN
# 27            MUHAMMAD  HABBI       NaN  ...         NaN     NaN        NaN
# 28          SHAIKHA FATMAWATI       NaN  ...         NaN     NaN        NaN
# 29                   SAMSUL         NaN  ...         NaN     NaN          √
# 30                        NaN       NaN  ...         NaN     NaN        NaN
# 31                        NaN       NaN  ...         NaN     NaN        NaN
# 32                        NaN       NaN  ...         NaN     NaN        NaN
# 33                        NaN       NaN  ...         NaN     NaN        NaN
# 34                        NaN       NaN  ...         NaN     NaN          √
# 35             DHENY FIRNANDI       NaN  ...         NaN     NaN        NaN
# 36                        NaN       NaN  ...         NaN     NaN        NaN
# 37                        NaN       NaN  ...         NaN     NaN        NaN
# 38                        NaN       NaN  ...         NaN     NaN        NaN
# 39                        NaN       NaN  ...         NaN     NaN        NaN
# 40                        NaN       NaN  ...         NaN     NaN        NaN
# 41                        NaN       NaN  ...         NaN     NaN        NaN
# 42                        NaN       NaN  ...         NaN     NaN        NaN
# 43                        NaN       NaN  ...         NaN     NaN        NaN
# 44                        NaN       NaN  ...         NaN     NaN        NaN
# 45                        NaN       NaN  ...         NaN     NaN        NaN
# 46                        NaN       NaN  ...         NaN     NaN        NaN
# 47                        NaN       NaN  ...         NaN     NaN        NaN
# 48                        NaN       NaN  ...         NaN     NaN        NaN
# 49                        NaN       NaN  ...         NaN     NaN        NaN
# 50                        NaN       NaN  ...         NaN     NaN        NaN
# 51                        NaN       NaN  ...         NaN     NaN        NaN
# 52                        NaN       NaN  ...         NaN     NaN        NaN
# 53                        NaN       NaN  ...         NaN     NaN        NaN
# 54                        NaN       NaN  ...         NaN     NaN        NaN
# 55                        NaN       NaN  ...         NaN     NaN        NaN
# 56                        NaN       NaN  ...         NaN     NaN        NaN
# 57                        NaN       NaN  ...         NaN     NaN        NaN
# 58                        NaN       NaN  ...         NaN     NaN        NaN
# 59                        NaN       NaN  ...         NaN     NaN        NaN
#
#    HT_Ayam HT_Bebek HT_Lele K_Mobil K_Motor Lainnya        Kategori
# 5        √      NaN     NaN     NaN     NaN     NaN       SEJAHTERA
# 6        √      NaN     NaN     NaN     NaN     NaN        MENENGAH
# 7      NaN      NaN     NaN     NaN     NaN     NaN        MENENGAH
# 8        √      NaN     NaN     NaN     NaN     NaN        MENENGAH
# 9        √      NaN     NaN     NaN     NaN     NaN       SEJAHTERA
# 10       √      NaN     NaN     NaN     NaN     NaN        MENENGAH
# 11     NaN      NaN     NaN     NaN     NaN     NaN        MENENGAH
# 12     NaN      NaN     NaN     NaN     NaN     NaN       SEJAHTERA
# 13     NaN      NaN     NaN     NaN     NaN     NaN       SEJAHTERA
# 14       √      NaN     NaN     NaN     NaN     NaN        MENENGAH
# 15     NaN      NaN     NaN     NaN     NaN     NaN        MENENGAH
# 16       √      NaN     NaN     NaN     NaN     NaN  PRA  SEJAHTERA
# 17       √      NaN     NaN     NaN     NaN     NaN        MENENGAH
# 18     NaN      NaN     NaN     NaN     NaN     NaN        MENENGAH
# 19     NaN      NaN     NaN     NaN     NaN     NaN       SEJAHTERA
# 20     NaN      NaN     NaN     NaN     NaN     NaN       SEJAHTERA
# 21       √        √     NaN     NaN     NaN     NaN       SEJAHTERA
# 22     NaN      NaN     NaN     NaN     NaN     NaN        MENENGAH
# 23     NaN      NaN     NaN     NaN     NaN     NaN        MENENGAH
# 24     NaN      NaN     NaN     NaN     NaN     NaN       SEJAHTERA
# 25       √      NaN     NaN     NaN     NaN     NaN        MENENGAH
# 26       √      NaN     NaN     NaN     NaN     NaN       SEJAHTERA
# 27     NaN      NaN     NaN     NaN     NaN     NaN       SEJAHTERA
# 28     NaN      NaN     NaN     NaN     NaN     NaN        MENENGAH
# 29     NaN      NaN     NaN     NaN     NaN     NaN        MENENGAH
# 30       √      NaN     NaN     NaN     NaN     NaN        MENENGAH
# 31     NaN      NaN     NaN     NaN     NaN     NaN        MENENGAH
# 32     NaN      NaN     NaN     NaN     NaN     NaN        MENENGAH
# 33     NaN      NaN     NaN     NaN     NaN     NaN  PRA  SEJAHTERA
# 34     NaN      NaN     NaN     NaN     NaN     NaN        MENENGAH
# 35     NaN      NaN     NaN     NaN     NaN     NaN        MENENGAH
# 36     NaN      NaN     NaN     NaN     NaN     NaN             NaN
# 37     NaN      NaN     NaN     NaN     NaN     NaN             NaN
# 38     NaN      NaN     NaN     NaN     NaN     NaN             NaN
# 39     NaN      NaN     NaN     NaN     NaN     NaN             NaN
# 40     NaN      NaN     NaN     NaN     NaN     NaN             NaN
# 41     NaN      NaN     NaN     NaN     NaN     NaN             NaN
# 42     NaN      NaN     NaN     NaN     NaN     NaN             NaN
# 43     NaN      NaN     NaN     NaN     NaN     NaN             NaN
# 44     NaN      NaN     NaN     NaN     NaN     NaN             NaN
# 45     NaN      NaN     NaN     NaN     NaN     NaN             NaN
# 46     NaN      NaN     NaN     NaN     NaN     NaN             NaN
# 47     NaN      NaN     NaN     NaN     NaN     NaN             NaN
# 48     NaN      NaN     NaN     NaN     NaN     NaN             NaN
# 49     NaN      NaN     NaN     NaN     NaN     NaN             NaN
# 50     NaN      NaN     NaN     NaN     NaN     NaN             NaN
# 51     NaN      NaN     NaN     NaN     NaN     NaN             NaN
# 52     NaN      NaN     NaN     NaN     NaN     NaN             NaN
# 53     NaN      NaN     NaN     NaN     NaN     NaN             NaN
# 54     NaN      NaN     NaN     NaN     NaN     NaN             NaN
# 55     NaN      NaN     NaN     NaN     NaN     NaN             NaN
# 56     NaN      NaN     NaN     NaN     NaN     NaN             NaN
# 57     NaN      NaN     NaN     NaN     NaN     NaN             NaN
# 58     NaN      NaN     NaN     NaN     NaN     NaN             NaN
# 59     NaN      NaN     NaN     NaN     NaN     NaN             NaN
#
# [55 rows x 38 columns]

# %%
KrajanRT02.shape
# Out:
# (55, 38)

# %% [markdown]
# ### RT03 - DROP 40-59

# %%
KrajanRT03 = pd.read_excel('ProyekDesa_Sedah/RekapSurveySensusDesaSedah/K20_KRAJAN/DATA PENDUDUK DUSUN SIDOREJO RT 01^J 02^J 03 KRAJAN RT 1,RT 2, RT 3 FIXX.xlsx', sheet_name='RT 3')
KrajanRT03 = KrajanRT03.iloc[5:]
KrajanRT03 = KrajanRT03.drop(KrajanRT03.columns[0], axis=1)
KrajanRT03.head(1)
# Out:
#   Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 5    KADIRAN        NaN     PETANI          -   MURIANA         NaN
#
#   Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10  ... Unnamed: 29 Unnamed: 30  \
# 5     PETANI        SD'        NaN         NaN  ...         NaN         NaN
#
#   Unnamed: 31 Unnamed: 32 Unnamed: 33 Unnamed: 34 Unnamed: 35 Unnamed: 36  \
# 5         NaN         NaN         NaN         NaN         NaN         NaN
#
#   Unnamed: 37 Unnamed: 38
# 5         NaN    MENENGAH
#
# [1 rows x 38 columns]

# %%
KrajanRT03.columns = ['Nama_Ayah', 'TTL_Ayah', 'Pekerjaan_Ayah', 'Pendidikan_Ayah',
                    'Nama_Ibu', 'TTL_Ibu', 'Pekerjaan_Ibu', 'Pendidikan_Ibu',
                    'Nama_Anak1', 'TTL_Anak1', 'Pekerjaan_Anak1', 'Pendidikan_Anak1',
                    'Nama_Anak2', 'TTL_Anak2', 'Pekerjaan_Anak2', 'Pendidikan_Anak2',
                    'Nama_Anak3', 'TTL_Anak3', 'Pekerjaan_Anak3', 'Pendidikan_Anak3',
                    'Nama_Anak4', 'TTL_Anak4', 'Pekerjaan_Anak4', 'Pendidikan_Anak4',
                    'RT_MilikSendiri', 'RT_IkutOrangTua', 'RT_Kontrak',
                    'Tanah_Sawah', 'Tanah_Kebun',
                    'HT_Sapi', 'HT_Kambing', 'HT_Ayam', 'HT_Bebek', 'HT_Lele',
                    'K_Mobil', 'K_Motor', 'Lainnya', 'Kategori'
                    ]

# %%
KrajanRT03.head(55)
# DROP INDEKS 40-59
# Out:
#             Nama_Ayah TTL_Ayah  \
# 5             KADIRAN      NaN
# 6              MISMAN      NaN
# 7        DANU ASMARA       NaN
# 8      PUGUH SANTOSO       NaN
# 9                 NaN      NaN
# 10             BASUNI      NaN
# 11            SUWANDI      NaN
# 12            SUTIKNO      NaN
# 13    TRIO HERWINSYAH      NaN
# 14           MISKANTO      NaN
# 15             MUSIN       NaN
# 16           HARIYONO      NaN
# 17             SUBANI      NaN
# 18      ZAMRONI YUSUF      NaN
# 19             SUGENG      NaN
# 20  MUHAMMAD ROSYIDIN      NaN
# 21     RIDWAN MUSTAFA      NaN
# 22             SUWITO      NaN
# 23         RENI  ANTO      NaN
# 24                NaN      NaN
# 25      HERI KUSWANTO      NaN
# 26         SYAMSYUDIN      NaN
# 27             SUROTO      NaN
# 28       AHMAD DAROJI      NaN
# 29            SAMSURI      NaN
# 30         AGUS YANTO      NaN
# 31            MARZUKI      NaN
# 32    SUGENG HARIANTO      NaN
# 33      AHMAD SUNARYO      NaN
# 34   NUR IKSAN KHOLIS      NaN
# 35           BAHRUDIN      NaN
# 36            SHUBARI      NaN
# 37            SUTIKNO      NaN
# 38           RUBIJIAN      NaN
# 39           SUPRAPTO      NaN
# 40                NaN      NaN
# 41                NaN      NaN
# 42                NaN      NaN
# 43                NaN      NaN
# 44                NaN      NaN
# 45                NaN      NaN
# 46                NaN      NaN
# 47                NaN      NaN
# 48                NaN      NaN
# 49                NaN      NaN
# 50                NaN      NaN
# 51                NaN      NaN
# 52                NaN      NaN
# 53                NaN      NaN
# 54                NaN      NaN
# 55      PRA SEJAHTERA        1
# 56           MENENGAH       27
# 57          SEJAHTERA        7
# 58                NaN      NaN
# 59                NaN      NaN
#
#                                       Pekerjaan_Ayah Pendidikan_Ayah  \
# 5                                             PETANI               -
# 6                                             PETANI              SD
# 7                                          WIRAUSAHA              D3
# 8                                     PERANGKAT DESA            SLTA
# 9                                                  _               _
# 10                                             PURNA               _
# 11                                            PETANI              SD
# 12                                             POLRI            SLTA
# 13                                  KLINIK KESEHATAN        SPK (D3)
# 14                                            PETANI             SMA
# 15                                            PETANI              SD
# 16                                        WIRASWASTA              D3
# 17                                               NaN              SD
# 18                                        WIRASWASTA            SLTA
# 19                                        WIRASWASTA              S1
# 20                                            PETANI             SMA
# 21                                   KARYAWAN SWASTA              S1
# 22                                         WIRAUSAHA             SMP
# 23                                            PETANI            SLTA
# 24                                               NaN             NaN
# 25                                            PETANI              SD
# 26                                               NaN             SMA
# 27                                       BURUHH TANI              SD
# 28                                        WIRASWASTA             SMA
# 29                                            PETANI             SMP
# 30  KEPALA SUB BIDANG BIMBINGAN DAN PENGENTASAN ANAK              S1
# 31                                            PETANI              SD
# 32                                        WIRASWASTA             STM
# 33                                PETANI/PENSIU GURU              D2
# 34                                            PETANI            SLTA
# 35                                            PETANI            SLTA
# 36                                               PNS              S1
# 37                                             POLRI             SMA
# 38                                        BURUH TANI              SD
# 39                                        BURUH TANI             NaN
# 40                                               NaN             NaN
# 41                                               NaN             NaN
# 42                                               NaN             NaN
# 43                                               NaN             NaN
# 44                                               NaN             NaN
# 45                                               NaN             NaN
# 46                                               NaN             NaN
# 47                                               NaN             NaN
# 48                                               NaN             NaN
# 49                                               NaN             NaN
# 50                                               NaN             NaN
# 51                                               NaN             NaN
# 52                                               NaN             NaN
# 53                                               NaN             NaN
# 54                                               NaN             NaN
# 55                                               NaN             NaN
# 56                                               NaN             NaN
# 57                                               NaN             NaN
# 58                                               NaN             NaN
# 59                                               NaN               \
#
#            Nama_Ibu TTL_Ibu Pekerjaan_Ibu Pendidikan_Ibu  \
# 5          MURIANA      NaN        PETANI            SD'
# 6           SUCIATI     NaN        PETANI            SD'
# 7     DELLA MARBELA     NaN     WIRAUSAHA             S1
# 8    SITI ROBINGAH      NaN           IRT            SMP
# 9    SITI ROKHMATIN     NaN     SERABUTAN            SD'
# 10         RUMKHANA     NaN           IRT            SMP
# 11              NaN     NaN           NaN            NaN
# 12      SRI HASTUTI     NaN           IRT           SLTA
# 13              NaN     NaN           NaN            NaN
# 14           SUMARI     NaN        PETANI             SD
# 15             NANI     NaN        PETANI            MTS
# 16      NURHIDAYATI     NaN           IRT            SMA
# 17           SAYUNA     NaN           IRT            NaN
# 18              ESA     NaN           NaN        S1 PGSD
# 19             RENI     NaN           NaN            S1
# 20             FEBI     NaN        PETANI             S1
# 21              NaN     NaN           NaN            NaN
# 22         HARNANIK     NaN           IRT            SMP
# 23          SUPARMI     NaN          IRT'            SMP
# 24           SUMINI     NaN           IRT             SD
# 25  AMINATUN ZURIAH     NaN        PETANI            MTS
# 26    RINA JULIANTI     NaN           NaN             D3
# 27         KASIATUN     NaN           IRT             SD
# 28         ERNAWATI     NaN           IRT             SD
# 29          DARWATI     NaN        PETANI             SD
# 30  USWATUN CASANAH     NaN           NaN             S1
# 31     SITI FATIMAH     NaN           NaN            SMP
# 32     ATIK WIDIAYI     NaN           NaN            SMA
# 33       UMI SAUDAH     NaN           NaN            SMP
# 34       SRI WAHUTI     NaN           NaN           SLTP
# 35    SITI NURJANAH     NaN           NaN           SLTA
# 36          KAETINI     NaN           NaN             SD
# 37      SRI HASTUTI     NaN           NaN            SMA
# 38              NaN     NaN           NaN            NaN
# 39         WARSIYEM     NaN           NaN             SD
# 40              NaN     NaN           NaN            NaN
# 41              NaN     NaN           NaN            NaN
# 42              NaN     NaN           NaN            NaN
# 43              NaN     NaN           NaN            NaN
# 44              NaN     NaN           NaN            NaN
# 45              NaN     NaN           NaN            NaN
# 46              NaN     NaN           NaN            NaN
# 47              NaN     NaN           NaN            NaN
# 48              NaN     NaN           NaN            NaN
# 49              NaN     NaN           NaN            NaN
# 50              NaN     NaN           NaN            NaN
# 51              NaN     NaN           NaN            NaN
# 52              NaN     NaN           NaN            NaN
# 53              NaN     NaN           NaN            NaN
# 54              NaN     NaN           NaN            NaN
# 55              NaN     NaN           NaN            NaN
# 56              NaN     NaN           NaN            NaN
# 57              NaN     NaN           NaN            NaN
# 58              NaN     NaN           NaN            NaN
# 59              NaN     NaN           NaN            NaN
#
#                    Nama_Anak1 TTL_Anak1  ... Tanah_Kebun HT_Sapi HT_Kambing  \
# 5                         NaN       NaN  ...         NaN     NaN        NaN
# 6                         NaN       NaN  ...         NaN     NaN        NaN
# 7                     NAUSHAD       NaN  ...         NaN     NaN        NaN
# 8                         NaN       NaN  ...         NaN     NaN        NaN
# 9         ALIYA RAHMA AZZAHRA       NaN  ...         NaN     NaN          √
# 10                        NaN       NaN  ...         NaN     NaN        NaN
# 11                        NaN       NaN  ...         NaN     NaN        NaN
# 12                        NaN       NaN  ...         NaN     NaN        NaN
# 13                      SACHI       NaN  ...         NaN     NaN        NaN
# 14           HERGA ARDIANSYAH       NaN  ...         NaN     NaN        NaN
# 15                        NaN       NaN  ...         NaN     NaN          √
# 16               EKA AGUSTINA       NaN  ...         NaN     NaN          √
# 17              AGUS BUDIYONO       NaN  ...         NaN     NaN        NaN
# 18                     NAGITA       NaN  ...         NaN     NaN        NaN
# 19                      ZIDAN       NaN  ...         NaN     NaN        NaN
# 20                       ASKA       NaN  ...         NaN     NaN        NaN
# 21                        NaN       NaN  ...         NaN     NaN        NaN
# 22                NURIL HAKIM       NaN  ...         NaN     NaN          √
# 23             RUDI KRISWANTO       NaN  ...         NaN     NaN          √
# 24                    SUKATI        NaN  ...         NaN     NaN        NaN
# 25             ARDI PRAWINATA       NaN  ...         NaN     NaN        NaN
# 26                    RASYA O       NaN  ...         NaN     NaN        NaN
# 27                        NaN       NaN  ...         NaN     NaN        NaN
# 28  BILQIS ZAHRA FAIRUS AHMAD       NaN  ...         NaN     NaN        NaN
# 29         DIVA PUTRA PRATAMA       NaN  ...         NaN       √        NaN
# 30     EDWIN MAHADIKA NUGRAHA       NaN  ...         NaN     NaN        NaN
# 31            ENDRAS ERNAWATI       NaN  ...         NaN     NaN        NaN
# 32                       WIDA       NaN  ...         NaN     NaN        NaN
# 33            USWATUN CASANAH       NaN  ...         NaN     NaN        NaN
# 34   AQILAH AULIA IZZATUNNISA       NaN  ...         NaN     NaN          √
# 35                        NaN       NaN  ...         NaN     NaN        NaN
# 36                        NaN       NaN  ...         NaN     NaN        NaN
# 37                        NaN       NaN  ...         NaN     NaN        NaN
# 38      MUHAMMAD IDRIS AFANDI       NaN  ...         NaN     NaN        NaN
# 39                        NaN       NaN  ...         NaN     NaN        NaN
# 40                        NaN       NaN  ...         NaN     NaN        NaN
# 41                        NaN       NaN  ...         NaN     NaN        NaN
# 42                        NaN       NaN  ...         NaN     NaN        NaN
# 43                        NaN       NaN  ...         NaN     NaN        NaN
# 44                        NaN       NaN  ...         NaN     NaN        NaN
# 45                        NaN       NaN  ...         NaN     NaN        NaN
# 46                        NaN       NaN  ...         NaN     NaN        NaN
# 47                        NaN       NaN  ...         NaN     NaN        NaN
# 48                        NaN       NaN  ...         NaN     NaN        NaN
# 49                        NaN       NaN  ...         NaN     NaN        NaN
# 50                        NaN       NaN  ...         NaN     NaN        NaN
# 51                        NaN       NaN  ...         NaN     NaN        NaN
# 52                        NaN       NaN  ...         NaN     NaN        NaN
# 53                        NaN       NaN  ...         NaN     NaN        NaN
# 54                        NaN       NaN  ...         NaN     NaN        NaN
# 55                        NaN       NaN  ...         NaN     NaN        NaN
# 56                        NaN       NaN  ...         NaN     NaN        NaN
# 57                        NaN       NaN  ...         NaN     NaN        NaN
# 58                        NaN       NaN  ...         NaN     NaN        NaN
# 59                        NaN       NaN  ...         NaN     NaN        NaN
#
#    HT_Ayam HT_Bebek HT_Lele K_Mobil K_Motor Lainnya      Kategori
# 5      NaN      NaN     NaN     NaN     NaN     NaN      MENENGAH
# 6        √      NaN     NaN     NaN     NaN     NaN      MENENGAH
# 7      NaN      NaN     NaN     NaN     NaN     NaN      MENENGAH
# 8      NaN      NaN     NaN     NaN     NaN     NaN      MENENGAH
# 9      NaN      NaN     NaN     NaN     NaN     NaN      MENENGAH
# 10     NaN      NaN     NaN     NaN     NaN     NaN      MENENGAH
# 11     NaN      NaN     NaN     NaN     NaN     NaN      MENENGAH
# 12     NaN      NaN     NaN     NaN     NaN     NaN     SEJAHTERA
# 13     NaN      NaN     NaN     NaN     NaN     NaN      MENENGAH
# 14     NaN      NaN     NaN     NaN     NaN     NaN      MENENGAH
# 15     NaN      NaN     NaN     NaN     NaN     NaN      MENENGAH
# 16     NaN      NaN       √     NaN     NaN     NaN     SEJAHTERA
# 17       √      NaN     NaN     NaN     NaN     NaN      MENENGAH
# 18     NaN      NaN     NaN     NaN     NaN     NaN      MENENGAH
# 19     NaN      NaN     NaN     NaN     NaN     NaN      MENENGAH
# 20     NaN      NaN     NaN     NaN     NaN     NaN      MENENGAH
# 21     NaN      NaN     NaN     NaN     NaN     NaN      MENENGAH
# 22     NaN      NaN     NaN     NaN     NaN     NaN      MENENGAH
# 23       √      NaN     NaN     NaN     NaN     NaN      MENENGAH
# 24       √      NaN     NaN     NaN     NaN     NaN      MENENGAH
# 25     NaN      NaN     NaN     NaN     NaN     NaN     SEJAHTERA
# 26     NaN      NaN     NaN     NaN     NaN     NaN  PRASEJAHTERA
# 27     NaN      NaN     NaN     NaN     NaN     NaN      MENENGAH
# 28     NaN      NaN     NaN     NaN     NaN     NaN      MENENGAH
# 29       √      NaN     NaN     NaN     NaN     NaN      MENENGAH
# 30     NaN      NaN     NaN     NaN     NaN     NaN     SEJAHTERA
# 31     NaN      NaN     NaN     NaN     NaN     NaN      MENENGAH
# 32     NaN      NaN     NaN     NaN     NaN     NaN      MENENGAH
# 33     NaN      NaN     NaN     NaN     NaN     NaN     SEJAHTERA
# 34     NaN      NaN     NaN     NaN     NaN     NaN      MENENGAH
# 35       √      NaN     NaN     NaN     NaN     NaN      MENENGAH
# 36     NaN      NaN     NaN     NaN     NaN     NaN     SEJAHTERA
# 37     NaN      NaN     NaN     NaN     NaN     NaN     SEJAHTERA
# 38     NaN      NaN     NaN     NaN     NaN     NaN      MENENGAH
# 39     NaN      NaN     NaN     NaN     NaN     NaN      MENENGAH
# 40     NaN      NaN     NaN     NaN     NaN     NaN           NaN
# 41     NaN      NaN     NaN     NaN     NaN     NaN           NaN
# 42     NaN      NaN     NaN     NaN     NaN     NaN           NaN
# 43     NaN      NaN     NaN     NaN     NaN     NaN           NaN
# 44     NaN      NaN     NaN     NaN     NaN     NaN           NaN
# 45     NaN      NaN     NaN     NaN     NaN     NaN           NaN
# 46     NaN      NaN     NaN     NaN     NaN     NaN           NaN
# 47     NaN      NaN     NaN     NaN     NaN     NaN           NaN
# 48     NaN      NaN     NaN     NaN     NaN     NaN           NaN
# 49     NaN      NaN     NaN     NaN     NaN     NaN           NaN
# 50     NaN      NaN     NaN     NaN     NaN     NaN           NaN
# 51     NaN      NaN     NaN     NaN     NaN     NaN           NaN
# 52     NaN      NaN     NaN     NaN     NaN     NaN           NaN
# 53     NaN      NaN     NaN     NaN     NaN     NaN           NaN
# 54     NaN      NaN     NaN     NaN     NaN     NaN           NaN
# 55     NaN      NaN     NaN     NaN     NaN     NaN           NaN
# 56     NaN      NaN     NaN     NaN     NaN     NaN           NaN
# 57     NaN      NaN     NaN     NaN     NaN     NaN           NaN
# 58     NaN      NaN     NaN     NaN     NaN     NaN           NaN
# 59     NaN      NaN     NaN     NaN     NaN     NaN           NaN
#
# [55 rows x 38 columns]

# %%
KrajanRT03.shape
# Out:
# (55, 38)

# %% [markdown]
# ### MERGE RT 1 2 3

# %%
Data_Krajan = pd.merge(KrajanRT01, KrajanRT02, on=['Nama_Ayah', 'TTL_Ayah', 'Pekerjaan_Ayah', 'Pendidikan_Ayah',
       'Nama_Ibu', 'TTL_Ibu', 'Pekerjaan_Ibu', 'Pendidikan_Ibu', 'Nama_Anak1',
       'TTL_Anak1', 'Pekerjaan_Anak1', 'Pendidikan_Anak1', 'Nama_Anak2',
       'TTL_Anak2', 'Pekerjaan_Anak2', 'Pendidikan_Anak2', 'Nama_Anak3',
       'TTL_Anak3', 'Pekerjaan_Anak3', 'Pendidikan_Anak3', 'Nama_Anak4',
       'TTL_Anak4', 'Pekerjaan_Anak4', 'Pendidikan_Anak4', 'RT_MilikSendiri',
       'RT_IkutOrangTua', 'RT_Kontrak', 'Tanah_Sawah', 'Tanah_Kebun',
       'HT_Sapi', 'HT_Kambing', 'HT_Ayam', 'HT_Bebek', 'HT_Lele', 'K_Mobil',
       'K_Motor', 'Lainnya', 'Kategori'], how='outer')
Data_Krajan = pd.merge(Data_Krajan, KrajanRT03, on=['Nama_Ayah', 'TTL_Ayah', 'Pekerjaan_Ayah', 'Pendidikan_Ayah',
       'Nama_Ibu', 'TTL_Ibu', 'Pekerjaan_Ibu', 'Pendidikan_Ibu', 'Nama_Anak1',
       'TTL_Anak1', 'Pekerjaan_Anak1', 'Pendidikan_Anak1', 'Nama_Anak2',
       'TTL_Anak2', 'Pekerjaan_Anak2', 'Pendidikan_Anak2', 'Nama_Anak3',
       'TTL_Anak3', 'Pekerjaan_Anak3', 'Pendidikan_Anak3', 'Nama_Anak4',
       'TTL_Anak4', 'Pekerjaan_Anak4', 'Pendidikan_Anak4', 'RT_MilikSendiri',
       'RT_IkutOrangTua', 'RT_Kontrak', 'Tanah_Sawah', 'Tanah_Kebun',
       'HT_Sapi', 'HT_Kambing', 'HT_Ayam', 'HT_Bebek', 'HT_Lele', 'K_Mobil',
       'K_Motor', 'Lainnya', 'Kategori'], how='outer')
# Out:
# <ipython-input-21-fa3ce8b0b350>:1: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   Data_Krajan = pd.merge(KrajanRT01, KrajanRT02, on=['Nama_Ayah', 'TTL_Ayah', 'Pekerjaan_Ayah', 'Pendidikan_Ayah',
# <ipython-input-21-fa3ce8b0b350>:1: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   Data_Krajan = pd.merge(KrajanRT01, KrajanRT02, on=['Nama_Ayah', 'TTL_Ayah', 'Pekerjaan_Ayah', 'Pendidikan_Ayah',
# <ipython-input-21-fa3ce8b0b350>:1: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   Data_Krajan = pd.merge(KrajanRT01, KrajanRT02, on=['Nama_Ayah', 'TTL_Ayah', 'Pekerjaan_Ayah', 'Pendidikan_Ayah',
# <ipython-input-21-fa3ce8b0b350>:1: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   Data_Krajan = pd.merge(KrajanRT01, KrajanRT02, on=['Nama_Ayah', 'TTL_Ayah', 'Pekerjaan_Ayah', 'Pendidikan_Ayah',
# <ipython-input-21-fa3ce8b0b350>:1: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   Data_Krajan = pd.merge(KrajanRT01, KrajanRT02, on=['Nama_Ayah', 'TTL_Ayah', 'Pekerjaan_Ayah', 'Pendidikan_Ayah',
# <ipython-input-21-fa3ce8b0b350>:1: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   Data_Krajan = pd.merge(KrajanRT01, KrajanRT02, on=['Nama_Ayah', 'TTL_Ayah', 'Pekerjaan_Ayah', 'Pendidikan_Ayah',
# <ipython-input-21-fa3ce8b0b350>:1: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   Data_Krajan = pd.merge(KrajanRT01, KrajanRT02, on=['Nama_Ayah', 'TTL_Ayah', 'Pekerjaan_Ayah', 'Pendidikan_Ayah',
# <ipython-input-21-fa3ce8b0b350>:1: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   Data_Krajan = pd.merge(KrajanRT01, KrajanRT02, on=['Nama_Ayah', 'TTL_Ayah', 'Pekerjaan_Ayah', 'Pendidikan_Ayah',
# <ipython-input-21-fa3ce8b0b350>:1: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   Data_Krajan = pd.merge(KrajanRT01, KrajanRT02, on=['Nama_Ayah', 'TTL_Ayah', 'Pekerjaan_Ayah', 'Pendidikan_Ayah',
# <ipython-input-21-fa3ce8b0b350>:1: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   Data_Krajan = pd.merge(KrajanRT01, KrajanRT02, on=['Nama_Ayah', 'TTL_Ayah', 'Pekerjaan_Ayah', 'Pendidikan_Ayah',
# <ipython-input-21-fa3ce8b0b350>:1: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   Data_Krajan = pd.merge(KrajanRT01, KrajanRT02, on=['Nama_Ayah', 'TTL_Ayah', 'Pekerjaan_Ayah', 'Pendidikan_Ayah',
# <ipython-input-21-fa3ce8b0b350>:1: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   Data_Krajan = pd.merge(KrajanRT01, KrajanRT02, on=['Nama_Ayah', 'TTL_Ayah', 'Pekerjaan_Ayah', 'Pendidikan_Ayah',
# <ipython-input-21-fa3ce8b0b350>:1: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   Data_Krajan = pd.merge(KrajanRT01, KrajanRT02, on=['Nama_Ayah', 'TTL_Ayah', 'Pekerjaan_Ayah', 'Pendidikan_Ayah',
# <ipython-input-21-fa3ce8b0b350>:1: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   Data_Krajan = pd.merge(KrajanRT01, KrajanRT02, on=['Nama_Ayah', 'TTL_Ayah', 'Pekerjaan_Ayah', 'Pendidikan_Ayah',
# <ipython-input-21-fa3ce8b0b350>:1: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   Data_Krajan = pd.merge(KrajanRT01, KrajanRT02, on=['Nama_Ayah', 'TTL_Ayah', 'Pekerjaan_Ayah', 'Pendidikan_Ayah',
# <ipython-input-21-fa3ce8b0b350>:1: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   Data_Krajan = pd.merge(KrajanRT01, KrajanRT02, on=['Nama_Ayah', 'TTL_Ayah', 'Pekerjaan_Ayah', 'Pendidikan_Ayah',
# <ipython-input-21-fa3ce8b0b350>:1: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   Data_Krajan = pd.merge(KrajanRT01, KrajanRT02, on=['Nama_Ayah', 'TTL_Ayah', 'Pekerjaan_Ayah', 'Pendidikan_Ayah',
# <ipython-input-21-fa3ce8b0b350>:10: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   Data_Krajan = pd.merge(Data_Krajan, KrajanRT03, on=['Nama_Ayah', 'TTL_Ayah', 'Pekerjaan_Ayah', 'Pendidikan_Ayah',
# <ipython-input-21-fa3ce8b0b350>:10: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   Data_Krajan = pd.merge(Data_Krajan, KrajanRT03, on=['Nama_Ayah', 'TTL_Ayah', 'Pekerjaan_Ayah', 'Pendidikan_Ayah',
# <ipython-input-21-fa3ce8b0b350>:10: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   Data_Krajan = pd.merge(Data_Krajan, KrajanRT03, on=['Nama_Ayah', 'TTL_Ayah', 'Pekerjaan_Ayah', 'Pendidikan_Ayah',
# <ipython-input-21-fa3ce8b0b350>:10: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   Data_Krajan = pd.merge(Data_Krajan, KrajanRT03, on=['Nama_Ayah', 'TTL_Ayah', 'Pekerjaan_Ayah', 'Pendidikan_Ayah',
# <ipython-input-21-fa3ce8b0b350>:10: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   Data_Krajan = pd.merge(Data_Krajan, KrajanRT03, on=['Nama_Ayah', 'TTL_Ayah', 'Pekerjaan_Ayah', 'Pendidikan_Ayah',
# <ipython-input-21-fa3ce8b0b350>:10: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   Data_Krajan = pd.merge(Data_Krajan, KrajanRT03, on=['Nama_Ayah', 'TTL_Ayah', 'Pekerjaan_Ayah', 'Pendidikan_Ayah',
# <ipython-input-21-fa3ce8b0b350>:10: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   Data_Krajan = pd.merge(Data_Krajan, KrajanRT03, on=['Nama_Ayah', 'TTL_Ayah', 'Pekerjaan_Ayah', 'Pendidikan_Ayah',
# <ipython-input-21-fa3ce8b0b350>:10: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   Data_Krajan = pd.merge(Data_Krajan, KrajanRT03, on=['Nama_Ayah', 'TTL_Ayah', 'Pekerjaan_Ayah', 'Pendidikan_Ayah',
# <ipython-input-21-fa3ce8b0b350>:10: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   Data_Krajan = pd.merge(Data_Krajan, KrajanRT03, on=['Nama_Ayah', 'TTL_Ayah', 'Pekerjaan_Ayah', 'Pendidikan_Ayah',
# <ipython-input-21-fa3ce8b0b350>:10: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   Data_Krajan = pd.merge(Data_Krajan, KrajanRT03, on=['Nama_Ayah', 'TTL_Ayah', 'Pekerjaan_Ayah', 'Pendidikan_Ayah',
# <ipython-input-21-fa3ce8b0b350>:10: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   Data_Krajan = pd.merge(Data_Krajan, KrajanRT03, on=['Nama_Ayah', 'TTL_Ayah', 'Pekerjaan_Ayah', 'Pendidikan_Ayah',
# <ipython-input-21-fa3ce8b0b350>:10: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   Data_Krajan = pd.merge(Data_Krajan, KrajanRT03, on=['Nama_Ayah', 'TTL_Ayah', 'Pekerjaan_Ayah', 'Pendidikan_Ayah',
# <ipython-input-21-fa3ce8b0b350>:10: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   Data_Krajan = pd.merge(Data_Krajan, KrajanRT03, on=['Nama_Ayah', 'TTL_Ayah', 'Pekerjaan_Ayah', 'Pendidikan_Ayah',

# %%
Data_Krajan.head(1)
# Out:
#    Nama_Ayah TTL_Ayah Pekerjaan_Ayah Pendidikan_Ayah       Nama_Ibu TTL_Ibu  \
# 0  ALI IMRON      NaN         TUKANG             SMA  SITI ANJARIAH     NaN
#
#   Pekerjaan_Ibu Pendidikan_Ibu Nama_Anak1 TTL_Anak1  ... Tanah_Kebun HT_Sapi  \
# 0          GURU             S1        NaN       NaN  ...         NaN     NaN
#
#   HT_Kambing HT_Ayam HT_Bebek HT_Lele K_Mobil K_Motor Lainnya  Kategori
# 0        NaN       √      NaN     NaN     NaN     NaN     NaN  MENENGAH
#
# [1 rows x 38 columns]

# %% [markdown]
# ### TOTAL DATA

# %%
Data_Krajan.shape
# Out:
# (1406, 38)

# %% [markdown]
# ## DUSUN SIDOREJO - REVISI

# %% [markdown]
# ### RT01 - AMAN

# %%
SidorejoRT01 = pd.read_excel('ProyekDesa_Sedah/RekapSurveySensusDesaSedah/K21_SIDOREJO/DATA PENDUDUK DUSUN SIDOREJO RT 01, 02, 03.xlsx', sheet_name='RT 01')
SidorejoRT01 = SidorejoRT01.iloc[5:]
SidorejoRT01 = SidorejoRT01.drop(SidorejoRT01.columns[0], axis=1)
SidorejoRT01.head(1)
# Out:
#      Unnamed: 1                 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 5  MOCH ZARKASI  PONOROGO, 05 AGUSTUS 1948  PENSIUNAN          -   MASNUNAH
#
#                    Unnamed: 6 Unnamed: 7 Unnamed: 8      Unnamed: 9  \
# 5  PONOROGO, 31 DESEMBER 1956  PENSIUNAN         S1  EVA HENDRAWATI
#
#              Unnamed: 10  ... Unnamed: 29 Unnamed: 30 Unnamed: 31 Unnamed: 32  \
# 5  PONOROGO, 29 MEI 1978  ...           √         NaN         NaN           √
#
#   Unnamed: 33 Unnamed: 34 Unnamed: 35 Unnamed: 36 Unnamed: 37 Unnamed: 38
# 5         NaN           √           √           √         NaN   SEJAHTERA
#
# [1 rows x 38 columns]

# %%
SidorejoRT01.columns = ['Nama_Ayah', 'TTL_Ayah', 'Pekerjaan_Ayah', 'Pendidikan_Ayah',
                    'Nama_Ibu', 'TTL_Ibu', 'Pekerjaan_Ibu', 'Pendidikan_Ibu',
                    'Nama_Anak1', 'TTL_Anak1', 'Pekerjaan_Anak1', 'Pendidikan_Anak1',
                    'Nama_Anak2', 'TTL_Anak2', 'Pekerjaan_Anak2', 'Pendidikan_Anak2',
                    'Nama_Anak3', 'TTL_Anak3', 'Pekerjaan_Anak3', 'Pendidikan_Anak3',
                    'Nama_Anak4', 'TTL_Anak4', 'Pekerjaan_Anak4', 'Pendidikan_Anak4',
                    'RT_MilikSendiri', 'RT_IkutOrangTua', 'RT_Kontrak',
                    'Tanah_Sawah', 'Tanah_Kebun',
                    'HT_Sapi', 'HT_Kambing', 'HT_Ayam', 'HT_Bebek', 'HT_Lele',
                    'K_Mobil', 'K_Motor', 'Lainnya', 'Kategori'
                    ]

# %%
SidorejoRT01.head(1)
# AMAN
# Out:
#       Nama_Ayah                   TTL_Ayah Pekerjaan_Ayah Pendidikan_Ayah  \
# 5  MOCH ZARKASI  PONOROGO, 05 AGUSTUS 1948      PENSIUNAN               -
#
#    Nama_Ibu                     TTL_Ibu Pekerjaan_Ibu Pendidikan_Ibu  \
# 5  MASNUNAH  PONOROGO, 31 DESEMBER 1956     PENSIUNAN             S1
#
#        Nama_Anak1              TTL_Anak1  ... Tanah_Kebun HT_Sapi HT_Kambing  \
# 5  EVA HENDRAWATI  PONOROGO, 29 MEI 1978  ...           √     NaN        NaN
#
#   HT_Ayam HT_Bebek HT_Lele K_Mobil K_Motor Lainnya   Kategori
# 5       √      NaN       √       √       √     NaN  SEJAHTERA
#
# [1 rows x 38 columns]

# %%
SidorejoRT01.shape
# Out:
# (39, 38)

# %% [markdown]
# ### RT02 - DROP 47-59

# %%
SidorejoRT02 = pd.read_excel('ProyekDesa_Sedah/RekapSurveySensusDesaSedah/K21_SIDOREJO/DATA PENDUDUK DUSUN SIDOREJO RT 01, 02, 03.xlsx', sheet_name='RT 02')
SidorejoRT02 = SidorejoRT02.iloc[5:]
SidorejoRT02 = SidorejoRT02.drop(SidorejoRT02.columns[0], axis=1)
SidorejoRT02.head(1)
# Out:
#          Unnamed: 1                  Unnamed: 2    Unnamed: 3 Unnamed: 4  \
# 5  Adi Marga Susila  Ponorogo, 18 Desember 1965  Pengangguran         S1
#
#   Unnamed: 5                   Unnamed: 6        Unnamed: 7 Unnamed: 8  \
# 5    Purwati  Bojonegoro, 17 Agustus 1965  Ibu Rumah Tangga        SMP
#
#              Unnamed: 9              Unnamed: 10  ... Unnamed: 29 Unnamed: 30  \
# 5  Wahyu Ghany Abdullah  Madiun, 24 Oktober 1997  ...         NaN         NaN
#
#   Unnamed: 31 Unnamed: 32 Unnamed: 33 Unnamed: 34 Unnamed: 35 Unnamed: 36  \
# 5         NaN           √         NaN         NaN         NaN           √
#
#   Unnamed: 37 Unnamed: 38
# 5         NaN    MENENGAH
#
# [1 rows x 38 columns]

# %%
SidorejoRT02.columns = ['Nama_Ayah', 'TTL_Ayah', 'Pekerjaan_Ayah', 'Pendidikan_Ayah',
                    'Nama_Ibu', 'TTL_Ibu', 'Pekerjaan_Ibu', 'Pendidikan_Ibu',
                    'Nama_Anak1', 'TTL_Anak1', 'Pekerjaan_Anak1', 'Pendidikan_Anak1',
                    'Nama_Anak2', 'TTL_Anak2', 'Pekerjaan_Anak2', 'Pendidikan_Anak2',
                    'Nama_Anak3', 'TTL_Anak3', 'Pekerjaan_Anak3', 'Pendidikan_Anak3',
                    'Nama_Anak4', 'TTL_Anak4', 'Pekerjaan_Anak4', 'Pendidikan_Anak4',
                    'RT_MilikSendiri', 'RT_IkutOrangTua', 'RT_Kontrak',
                    'Tanah_Sawah', 'Tanah_Kebun',
                    'HT_Sapi', 'HT_Kambing', 'HT_Ayam', 'HT_Bebek', 'HT_Lele',
                    'K_Mobil', 'K_Motor', 'Lainnya', 'Kategori'
                    ]

# %%
SidorejoRT02.head(1)
# DROP INDEKS 47-59
# Out:
#           Nama_Ayah                    TTL_Ayah Pekerjaan_Ayah  \
# 5  Adi Marga Susila  Ponorogo, 18 Desember 1965   Pengangguran
#
#   Pendidikan_Ayah Nama_Ibu                      TTL_Ibu     Pekerjaan_Ibu  \
# 5              S1  Purwati  Bojonegoro, 17 Agustus 1965  Ibu Rumah Tangga
#
#   Pendidikan_Ibu            Nama_Anak1                TTL_Anak1  ...  \
# 5            SMP  Wahyu Ghany Abdullah  Madiun, 24 Oktober 1997  ...
#
#   Tanah_Kebun HT_Sapi HT_Kambing HT_Ayam HT_Bebek HT_Lele K_Mobil K_Motor  \
# 5         NaN     NaN        NaN       √      NaN     NaN     NaN       √
#
#   Lainnya  Kategori
# 5     NaN  MENENGAH
#
# [1 rows x 38 columns]

# %%
SidorejoRT02.shape
# Out:
# (55, 38)

# %% [markdown]
# ### RT03 - AMAN

# %%
SidorejoRT03 = pd.read_excel('ProyekDesa_Sedah/RekapSurveySensusDesaSedah/K21_SIDOREJO/DATA PENDUDUK DUSUN SIDOREJO RT 01, 02, 03.xlsx', sheet_name='RT 03')
SidorejoRT03 = SidorejoRT03.iloc[5:]
SidorejoRT03 = SidorejoRT03.drop(SidorejoRT03.columns[0], axis=1)
SidorejoRT03.head(1)
# Out:
#   Unnamed: 1                  Unnamed: 2  Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 5   SUPRIADI  PONOROGO, 16 FEBRUARI 1973  WIRASWASTA       SLTP    MURYATI
#
#                   Unnamed: 6  Unnamed: 7 Unnamed: 8           Unnamed: 9  \
# 5  PONOROGO, 17 OKTOBER 1980  WIRASWASTA         SD  AISAH PUTRI PRATIWI
#
#                  Unnamed: 10  ... Unnamed: 29 Unnamed: 30 Unnamed: 31  \
# 5  PONOROGO, 23 OKTOBER 2005  ...           -           -           -
#
#   Unnamed: 32 Unnamed: 33 Unnamed: 34 Unnamed: 35 Unnamed: 36 Unnamed: 37  \
# 5           -           -           -           -           √         NaN
#
#   Unnamed: 38
# 5    MENENGAH
#
# [1 rows x 38 columns]

# %%
SidorejoRT03.columns = ['Nama_Ayah', 'TTL_Ayah', 'Pekerjaan_Ayah', 'Pendidikan_Ayah',
                    'Nama_Ibu', 'TTL_Ibu', 'Pekerjaan_Ibu', 'Pendidikan_Ibu',
                    'Nama_Anak1', 'TTL_Anak1', 'Pekerjaan_Anak1', 'Pendidikan_Anak1',
                    'Nama_Anak2', 'TTL_Anak2', 'Pekerjaan_Anak2', 'Pendidikan_Anak2',
                    'Nama_Anak3', 'TTL_Anak3', 'Pekerjaan_Anak3', 'Pendidikan_Anak3',
                    'Nama_Anak4', 'TTL_Anak4', 'Pekerjaan_Anak4', 'Pendidikan_Anak4',
                    'RT_MilikSendiri', 'RT_IkutOrangTua', 'RT_Kontrak',
                    'Tanah_Sawah', 'Tanah_Kebun',
                    'HT_Sapi', 'HT_Kambing', 'HT_Ayam', 'HT_Bebek', 'HT_Lele',
                    'K_Mobil', 'K_Motor', 'Lainnya', 'Kategori'
                    ]

# %%
SidorejoRT03.head(49)
# AMAN
# Out:
#                    Nama_Ayah                     TTL_Ayah      Pekerjaan_Ayah  \
# 5                   SUPRIADI   PONOROGO, 16 FEBRUARI 1973          WIRASWASTA
# 6              IMRON ZUBAIDI       PONOROGO, 29 JULI 1977          WIRASWASTA
# 7              SUGENG RIYADI     KEDIRI, 30 NOVEMBER 1970              SWASTA
# 8              ALM. MUHTAROM                            -                   -
# 9   FAIZ FARUKI AL-KHUDZAIFI    PONOROGO, 12 AGUSTUS 1994              SWASTA
# 10                   MUZAYIN      PONOROGO, 26 MARET 1969                TANI
# 11               ABDUL MANAF         MADIUN, 7 MARET 1979     KARYAWAN SWASTA
# 12                         -                            -                   -
# 13                  MUSTAJAB        PONOROGO, 30 MEI 1957                TANI
# 14             FANANI AFANDI   PONOROGO, 24 NOVEMBER 1968              SWASTA
# 15                    FUDOLI        PONOROGO, 23 DESEMBER               SOPIR
# 16             HERI KUSWANTO     PONOROGO, 4 JANUARI 1957                   -
# 17                  MUSTAQIM         MALANG, 3 MARET 1980     KARYAWAN SWASTA
# 18                         -                            -                   -
# 19                      SENI     PONOROGO, 6 AGUSTUS 1968  BURUH HARIAN LEPAS
# 20             DOFIR MASRURI       PONOROGO, 6 MARET 1976              PETANI
# 21                   SUKARJI            MADIUN, 15 - 1964           PENSIUNAN
# 22       TRISNO BADARUL ULUM       PONOROGO, 5 APRIL 1982          WIRASWASTA
# 23           KHOLIQ BAHTIAR     PONOROGO, 5 DESEMBER 1985          WIRASWASTA
# 24                    SLAMET                     PONOROGO          WIRASWASTA
# 25                MOH. DAWAM          KEDIRI, 10 MEI 1960              SWASTA
# 26       DEA AGUNG WICAKSONO     MADIUN, 13 DESEMBER 1991                   -
# 27                         -                            -                   -
# 28            KHOIRUL ABIDIN   PONOROGO, 24 DESEMBER 1972                 PNS
# 29             TULUS WAHYUDI    PONOROGO, 16 AGUSTUS 1969          WIRASWASTA
# 30                   SUHARTO  PONOROGO, 18 SEPTEMBER 1962              PETANI
# 31                 AFTORUDIN       PONOROGO, 10 JUNI 1967              SWASTA
# 32          MUHAMMAD MAGHFUR   PONOROGO, 20 FEBRUARI 1975     KARYAWAN SWASTA
# 33       ANDIK HADI SISWANTO  PONOROGO, 10 SEPTEMBER 1979          WIRASWASTA
# 34               ALI MUSTOFA        PONOROGO, 14 MEI 1978               BURUH
# 35             SLAMET WIDODO    PONOROGO, 1 DESEMBER 1972              SWASTA
# 36                   DIMYATI       PONOROGO, 30 JUNI 1954              PETANI
# 37                  WIJIANTO  PONOROGO, 28 SEPTEMBER 1968          WIRASWASTA
# 38              FATHURROHMAN         MADIUN, 15 JULI 1998          WIRASWASTA
# 39                    SUYONO                     PONOROGO          WIRASWASTA
# 40                   SUKAMTO   PONOROGO, 10 FEBRUARI 1940              PETANI
# 41                M. DAROINI   PONOROGO, 22 DESEMBER 1950              SWASTA
# 42              IBNU ATOILAH                 1 MARET 1967              SWASTA
# 43           DONY WIDIANARKO      PONOROGO, 17 APRIL 1979              PETANI
# 44             ZAINUL ARIFIN   PONOROGO, 12 FEBRUARI 1970          WIRASWASTA
# 45       AMANG FATCHURRAHMAN      MADIUN 26 DESEMBER 1986              SWASTA
# 46                       NaN                          NaN                 NaN
# 47         KHORIP IKHSANUDIN       PONOROGO, 31 JULI 1983          WIRASWASTA
# 48                     LAMUN     MADIUN, 16 FEBRUARI 1966              PETANI
# 49                    FARHAN        SERANG, 14 MARET 2000              SWASTA
# 50                    KADENI        PONOROGO, 13 MEI 1963              PETANI
# 51       SEPTIAN ANDRIWIJAYA   PONOROGO, 2 SEPTEMBER 1985              PETANI
# 52              JOKO SETIONO     PONOROGO, 5 OKTOBER 1983     KARYAWAN SWASTA
# 53        MUHAMMAD NASTANGIN    PONOROGO, 3 DESEMBER 1973              PETANI
#
#    Pendidikan_Ayah                     Nama_Ibu                       TTL_Ibu  \
# 5             SLTP                      MURYATI     PONOROGO, 17 OKTOBER 1980
# 6             SLTA                     ISMIATIN        PONOROGO, 19 JULI 1977
# 7             SLTA               ANA INDIYAWATI        PONOROGO, 4 MARET 1977
# 8                -            ENDANG SUPRIHATIN   PONOROGO, 26 SEPTEMBER 1966
# 9             SLTA   FRISKA NUR'AINI NOVITASARI    PONOROGO, 27 NOVEMBER 1992
# 10            SLTA                  PUJI ASTUTI         PONOROGO, 8 JULI 1976
# 11            SLTA            ANISATUL FADLILAH      PONOROGO, 1 AGUSTUS 1986
# 12               -                    SUPIYATUN     PONOROGO, 4 FEBRUARI 1939
# 13            SLTP                  UMI NURYANI         PONOROGO, 9 JULI 1965
# 14            PGAN                  SRI MULYANI     PONOROGO, 26 OKTOBER 1975
# 15              SD           LAILATUL MUHAR0MAH         PONOROGO, 21 NOVEMBER
# 16            SLTA                 SITI NUASIAH        PONOROGO, 20 JUNI 1980
# 17              D1         RENY ANDHIKA HAPSARI  TRENGGALEK, 25 NOVEMBER 1984
# 18               -             ENI DWI WINARSIH     PONOROGO, 31 AGUSTUS 1963
# 19   TIDAK SEKOLAH           RINI DWI RATNASARI     PONOROGO, 25 OKTOBER 1983
# 20            SLTA                ERNA ZUNAIDAH        PONOROGO, 30 JUNI 1977
# 21               -                      SURYANI          MADIUN, 1 APRIL 1975
# 22          ALIYAH              RINA KUSUMAWATI      MAGETAN, 11 JANUARI 1987
# 23            SLTA           INDAH WIDYANINGSIH          MADIUN, 28 JUNI 1992
# 24            SLTP                     ASRINGAH                      PONOROGO
# 25            SLTP            SRI RAHAYU WIDODO      PONOROGO, 8 AGUSTUS 1961
# 26             SMK           DIAN SRI WULANDARI     PONOROGO, 18 JANUARI 1990
# 27               -                     SUKATIN         PONOROGO, 25 JUNI 1957
# 28            SLTA               WIWIK ERNAWATI    PONOROGO, 15 DESEMBER 1974
# 29              SD                LILIK HERLINA       PONOROGO, 24 MARET 1975
# 30            SLTP                UMI MUJAYANAH     PONOROGO, 3 FEBRUARI 1966
# 31              SD                  IDA SUNARTI          PONOROGO, 2 MEI 1967
# 32            SLTA                            -                             -
# 33            SLTA                  WENI ASTUTI         PACITAN, 29 JUNI 1980
# 34            SLTA                     WINARSIH   TRENGGALEK, 27 AGUSTUS 1985
# 35            SLTA             DWI PUJI LESTARI       PONOROGO, 25 MARET 1983
# 36              SD                          NaN                           NaN
# 37            SLTP                     SULASTRI     JOMBANG, 5 SEPTEMBER 1979
# 38            SLTA               IKA NOVITASARI        PONOROGO, 27 JUNI 1997
# 39            SLTP                 SITI JUARIAH                      PONOROGO
# 40              SD                      WIDJATI        PONOROGO, 2 APRIL 1954
# 41            SLTA                      SUNDARI    PONOROGO, 23 FEBRUARI 1959
# 42            SLTP               TITIK SRIYATIN                 21 MARET 1972
# 43            SLTA                  SITI ROFIAH       LAMPUNG, 1 JANUARI 1984
# 44            SLTA                    NURJANNAH           INHIL, 21 JULI 1976
# 45             SMK  GIZLIYA WAHYU SETYA WARDANI     PONOROGO, 27 AGUSTUS 1987
# 46             NaN                       MISTUN        PONOROGO, 30 JUNI 1966
# 47             SMA                     MARIATIN     PONOROGO, 28 AGUSTUS 1959
# 48              SD                    UPRIYANTI     PONOROGO, 2 DESEMBER 1976
# 49            SLTP              VIVI FRIDAYANTI     PONOROGO, 28 AGUSTUS 1995
# 50            SLTA             HANINGMAS KIYATI        PONOROGO, 20 JUNI 1966
# 51            SLTA              FARIDA YASTANTI         PONOROGO, 13 MEI 1954
# 52            SLTA       MAS AYU YUNIAWATISNANI   MALUKU TENGAH, 13 JUNI 1992
# 53            SLTA                          NaN                           NaN
#
#        Pekerjaan_Ibu Pendidikan_Ibu                     Nama_Anak1  \
# 5         WIRASWASTA             SD            AISAH PUTRI PRATIWI
# 6                PNS             D4   NAUFAL RIATTA AHADAN ZUBAIDI
# 7             SWASTA           SLTA           KUNCORO BAYU SAPUTRO
# 8         BURUH TANI           SLTA      TAFIDA NUR LAILY AZIZATIN
# 9                  -           SLTA                              -
# 10        WIRASWASTA           SLTP                ADAM FIRMANSYAH
# 11   KARYAWAN SWASTA             S1         JAISYAN ILHAM MUHAMMAD
# 12                 -             SD                     MOH. YASIN
# 13                 -           SLTA                   KHOIRUL ANAM
# 14            SWASTA           SLTA                  RAIHAN AFANDI
# 15      GURU HONORER             S1  DINARA LATIZA LAILI BRILLIANT
# 16  IBU RUMAH TANGGA           SLTA                   FAHRUL RIZKY
# 17               PNS             S1            KALYCA AIESYA INARA
# 18        WIRASWASTA           SLTP             TANTI EKO BUDIARTI
# 19  IBU RUMAH TANGGA           SLTA                  AHMAD FATHONI
# 20  IBU RUMAH TANGGA           SLTP                YAZID ABIL WAFA
# 21            PETANI           SLTA               EMILYA FEBRIANTI
# 22        WIRASWASTA           SLTA       ANNISA SHALAWATI AZZAHRA
# 23  IBU RUMAH TANGGA           SLTA                       ZULFADLI
# 24        WIRASWASTA           SLTA              OKTA DWI KHARISMA
# 25                 -           SLTP               AMANG FATUROHMAN
# 26  IBU RUMAH TANGGA           SLTA     ARACHELLY SATIVA WICAKSONO
# 27                 -             SD                YETIK INDRAWATI
# 28        WIRASWASTA           SLTA            ERISKA DEWI PRATIWI
# 29        WIRASWASTA           SLTP                DIKA WAHYUDIN P
# 30  IBU RUMAH TANGGA           SLTA                              -
# 31  IBU RUMAH TANGGA           SLTP                VIVI FRIDAYANTI
# 32                 -              -                              -
# 33        WIRASWASTA           SLTP              WINDY ELISA PUTRI
# 34  IBU RUMAH TANGGA           SLTA            M. NAUFAL AL'AYYUBI
# 35  IBU RUMAH TANGGA           SLTA                              -
# 36               NaN            NaN                WIWIT FEBRIYANI
# 37        WIRASWASTA           SLTP                 IKA NOVITASARI
# 38   KARYAWAN SWASTA           SLTA       M. ALBY PASHA NATANAGARA
# 39          PEDAGANG           SLTP               MUHHAMAD YOSINDA
# 40        PETANI/IRT             SD                    ANGGA ROY S
# 41            SWASTA           SLTA         VITA KHALIMATUSSA'DIAH
# 42            SWASTA           SLTP           LENI SEPTIAN DANUATI
# 43               NaN           SLTA     MARSYA AWRA PUTRI BATRISIA
# 44            SWASTA             D3         MUHAMMAD DIMAS ALFAJOR
# 45               IRT        SARJANA                            NaN
# 46        WIRASWASTA           SLTP                            NaN
# 47               IRT            NaN                            NaN
# 48               IRT           SLTA                            NaN
# 49               NaN            SMA                            NaN
# 50            PETANI           SLTP                            NaN
# 51               IRT           SLTA                            NaN
# 52     KARYAWAN BUMN             S1            ROBBY HAFID MAULANA
# 53               NaN            NaN                            NaN
#
#                        TTL_Anak1  ... Tanah_Kebun HT_Sapi HT_Kambing HT_Ayam  \
# 5      PONOROGO, 23 OKTOBER 2005  ...           -       -          -       -
# 6     PONOROGO, 11 FEBRUARI 2007  ...           -       -          -       -
# 7         PONOROGO, 17 JUNI 1996  ...           -       -          -       √
# 8         PONOROGO, 30 JULI 2004  ...           -       -          -       -
# 9                              -  ...           -       -          -       -
# 10   PONOROGO, 16 SEPTEMBER 2002  ...           -       -          -       -
# 11       PONOROGO, 17 APRIL 2022  ...           -       -          -       √
# 12   PONOROGO, 11 SEPTEMBER 1975  ...           -       -          √       √
# 13                             -  ...           -       -          √       -
# 14    PONOROGO, 24 DESEMBER 2005  ...           √       -          √       -
# 15       PONOROGO, 23 SEPTEMBER   ...           -       -          -       -
# 16     PONOROGO, 4 NOVEMBER 2001  ...           -       -          -       -
# 17  TRENGGALEK, 23 DESEMBER 2011  ...           -       -          -       -
# 18     PONOROGO, 31 AGUSTUS 1980  ...           -       -          -       √
# 19     PONOROGO, 6 DESEMBER 2003  ...           -       -          -       -
# 20        PONOROGO, 11 JULI 2008  ...           -       -          -       -
# 21      MADIUN, 28 FEBRUARI 2001  ...           -       -          -       √
# 22        BERAU, 16 OKTOBER 2013  ...           -       -          -       -
# 23           MADIUN, 6 JUNI 2017  ...           -       -          -       -
# 24                      PONOROGO  ...           -       -          -       -
# 25      MADIUN, 26 DESEMBER 1986  ...           -       -          -       √
# 26     PONOROGO, 8 DESEMBER 2016  ...           -       -          -       -
# 27         PONOROGO, 5 JULI 1974  ...           -       -          -       √
# 28        PONOROGO, 25 JUNI 1998  ...           -       -          -       √
# 29     PONOROGO, 29 JANUARI 2001  ...           -       -          -       -
# 30                             -  ...           -       -          √       -
# 31     PONOROGO, 28 AGUSTUS 1995  ...           -       -          -       -
# 32                             -  ...           -       -          -       -
# 33       PONOROGO, 29 MARET 2010  ...           -       -          -       √
# 34   PONOROGO, 21 SEPTEMBER 2009  ...           -       -          -       -
# 35                             -  ...           -       -          -       -
# 36    PONOROGO, 19 FEBRUARI 1981  ...           -       -          -       -
# 37        PONOROGO, 27 JUNI 1997  ...         NaN     NaN        NaN       √
# 38        PONOROGO, 24 JULI 2019  ...         NaN     NaN        NaN       √
# 39                      PONOROGO  ...         NaN     NaN        NaN     NaN
# 40        PONOROGO, 3 APRIL 1995  ...           √     NaN        NaN       √
# 41    PONOROGO, 31 NOVEMBER 1979  ...         NaN     NaN        NaN     NaN
# 42           1991-09-06 00:00:00  ...         NaN     NaN        NaN     NaN
# 43         LAMPUNG, 21 JULI 2009  ...         NaN     NaN        NaN     NaN
# 44        PONOROGO, 17 JUNI 2005  ...         NaN     NaN        NaN     NaN
# 45                           NaN  ...         NaN     NaN        NaN       √
# 46                           NaN  ...         NaN     NaN        NaN       √
# 47                           NaN  ...         NaN     NaN        NaN     NaN
# 48                           NaN  ...         NaN     NaN        NaN       √
# 49                           NaN  ...         NaN     NaN        NaN     NaN
# 50                           NaN  ...         NaN     NaN        NaN     NaN
# 51                           NaN  ...         NaN     NaN        NaN       √
# 52       PONOROGO, 30 APRIL 2018  ...         NaN     NaN        NaN     NaN
# 53                           NaN  ...         NaN     NaN        NaN     NaN
#
#    HT_Bebek HT_Lele K_Mobil K_Motor Lainnya      Kategori
# 5         -       -       -       √     NaN      MENENGAH
# 6         -       -       √       √     NaN     SEJAHTERA
# 7         -       -       √       √     NaN     SEJAHTERA
# 8         -       -       -       √     NaN  PRASEJAHTERA
# 9         -       -       -       √     NaN      MENENGAH
# 10        -       -       -       √     NaN      MENENGAH
# 11        -       -       -       √     NaN      MENENGAH
# 12        -       -       -       √     NaN  PRASEJAHTERA
# 13        -       -       -       √     NaN      MENENGAH
# 14        -       -       √       √     NaN     SEJAHTERA
# 15        -       -       √       √     NaN     SEJAHTERA
# 16        -       -       -       √     NaN      MENENGAH
# 17        -       -       -       √     NaN      MENENGAH
# 18        -       -       -       √     NaN      MENENGAH
# 19        √       -       -       √     NaN      MENENGAH
# 20        -       -       -       √     NaN      MENENGAH
# 21        -       √       -       √     NaN     SEJAHTERA
# 22        -       -       √       √     NaN     SEJAHTERA
# 23        -       -       -       √     NaN  PRASEJAHTERA
# 24        -       -       -       √     NaN      MENENGAH
# 25        -       -       -       -     NaN      MENENGAH
# 26        -       -       -       -     NaN  PRASEJAHTERA
# 27        -       -       -       -     NaN  PRASEJAHTERA
# 28        -       -       -       √     NaN     SEJAHTERA
# 29        -       -       -       -     NaN      MENENGAH
# 30        -       -       -       √     NaN  PRASEJAHTERA
# 31        -       -       -       √     NaN  PRASEJAHTERA
# 32        -       -       -       √     NaN  PRASEJAHTERA
# 33        -       -       -       √     NaN      MENENGAH
# 34        -       -       -       √     NaN      MENENGAH
# 35        -       -       -       √     NaN      MENENGAH
# 36        -       -       -       √     NaN      MENENGAH
# 37      NaN     NaN     NaN       √     NaN      MENENGAH
# 38      NaN     NaN     NaN       √     NaN      MENENGAH
# 39      NaN     NaN     NaN       √     NaN      MENENGAH
# 40      NaN     NaN     NaN       √     NaN      MENENGAH
# 41      NaN     NaN       √       √     NaN  PRASEJAHTERA
# 42      NaN     NaN     NaN     NaN     NaN      MENENGAH
# 43      NaN     NaN     NaN       √     NaN      MENENGAH
# 44      NaN     NaN     NaN       √     NaN      MENENGAH
# 45      NaN     NaN     NaN     NaN     NaN      MENENGAH
# 46      NaN     NaN     NaN       √     NaN      MENENGAH
# 47      NaN     NaN     NaN     NaN     NaN      MENENGAH
# 48      NaN     NaN     NaN       √     NaN      MENENGAH
# 49      NaN     NaN     NaN     NaN     NaN  PRASEJAHTERA
# 50      NaN     NaN     NaN     NaN     NaN  PRASEJAHTERA
# 51      NaN     NaN     NaN       √     NaN      MENENGAH
# 52      NaN     NaN     NaN     NaN     NaN  PRASEJAHTERA
# 53      NaN     NaN     NaN       √     NaN      MENENGAH
#
# [49 rows x 38 columns]

# %%
SidorejoRT03.shape
# Out:
# (49, 38)

# %% [markdown]
# ### MERGE RT 1 2 3

# %%
SidorejoRT01.columns
# Out:
# Index(['Nama_Ayah', 'TTL_Ayah', 'Pekerjaan_Ayah', 'Pendidikan_Ayah',
#        'Nama_Ibu', 'TTL_Ibu', 'Pekerjaan_Ibu', 'Pendidikan_Ibu', 'Nama_Anak1',
#        'TTL_Anak1', 'Pekerjaan_Anak1', 'Pendidikan_Anak1', 'Nama_Anak2',
#        'TTL_Anak2', 'Pekerjaan_Anak2', 'Pendidikan_Anak2', 'Nama_Anak3',
#        'TTL_Anak3', 'Pekerjaan_Anak3', 'Pendidikan_Anak3', 'Nama_Anak4',
#        'TTL_Anak4', 'Pekerjaan_Anak4', 'Pendidikan_Anak4', 'RT_MilikSendiri',
#        'RT_IkutOrangTua', 'RT_Kontrak', 'Tanah_Sawah', 'Tanah_Kebun',
#        'HT_Sapi', 'HT_Kambing', 'HT_Ayam', 'HT_Bebek', 'HT_Lele', 'K_Mobil',
#        'K_Motor', 'Lainnya', 'Kategori'],
#       dtype='object')

# %%
SidorejoRT02.columns
# Out:
# Index(['Nama_Ayah', 'TTL_Ayah', 'Pekerjaan_Ayah', 'Pendidikan_Ayah',
#        'Nama_Ibu', 'TTL_Ibu', 'Pekerjaan_Ibu', 'Pendidikan_Ibu', 'Nama_Anak1',
#        'TTL_Anak1', 'Pekerjaan_Anak1', 'Pendidikan_Anak1', 'Nama_Anak2',
#        'TTL_Anak2', 'Pekerjaan_Anak2', 'Pendidikan_Anak2', 'Nama_Anak3',
#        'TTL_Anak3', 'Pekerjaan_Anak3', 'Pendidikan_Anak3', 'Nama_Anak4',
#        'TTL_Anak4', 'Pekerjaan_Anak4', 'Pendidikan_Anak4', 'RT_MilikSendiri',
#        'RT_IkutOrangTua', 'RT_Kontrak', 'Tanah_Sawah', 'Tanah_Kebun',
#        'HT_Sapi', 'HT_Kambing', 'HT_Ayam', 'HT_Bebek', 'HT_Lele', 'K_Mobil',
#        'K_Motor', 'Lainnya', 'Kategori'],
#       dtype='object')

# %%
SidorejoRT03.columns
# Out:
# Index(['Nama_Ayah', 'TTL_Ayah', 'Pekerjaan_Ayah', 'Pendidikan_Ayah',
#        'Nama_Ibu', 'TTL_Ibu', 'Pekerjaan_Ibu', 'Pendidikan_Ibu', 'Nama_Anak1',
#        'TTL_Anak1', 'Pekerjaan_Anak1', 'Pendidikan_Anak1', 'Nama_Anak2',
#        'TTL_Anak2', 'Pekerjaan_Anak2', 'Pendidikan_Anak2', 'Nama_Anak3',
#        'TTL_Anak3', 'Pekerjaan_Anak3', 'Pendidikan_Anak3', 'Nama_Anak4',
#        'TTL_Anak4', 'Pekerjaan_Anak4', 'Pendidikan_Anak4', 'RT_MilikSendiri',
#        'RT_IkutOrangTua', 'RT_Kontrak', 'Tanah_Sawah', 'Tanah_Kebun',
#        'HT_Sapi', 'HT_Kambing', 'HT_Ayam', 'HT_Bebek', 'HT_Lele', 'K_Mobil',
#        'K_Motor', 'Lainnya', 'Kategori'],
#       dtype='object')

# %%
Data_Sidorejo = pd.merge(SidorejoRT01, SidorejoRT02, on=['Nama_Ayah', 'TTL_Ayah', 'Pekerjaan_Ayah', 'Pendidikan_Ayah',
       'Nama_Ibu', 'TTL_Ibu', 'Pekerjaan_Ibu', 'Pendidikan_Ibu', 'Nama_Anak1',
       'TTL_Anak1', 'Pekerjaan_Anak1', 'Pendidikan_Anak1', 'Nama_Anak2',
       'TTL_Anak2', 'Pekerjaan_Anak2', 'Pendidikan_Anak2', 'Nama_Anak3',
       'TTL_Anak3', 'Pekerjaan_Anak3', 'Pendidikan_Anak3', 'Nama_Anak4',
       'TTL_Anak4', 'Pekerjaan_Anak4', 'Pendidikan_Anak4', 'RT_MilikSendiri',
       'RT_IkutOrangTua', 'RT_Kontrak', 'Tanah_Sawah', 'Tanah_Kebun',
       'HT_Sapi', 'HT_Kambing', 'HT_Ayam', 'HT_Bebek', 'HT_Lele', 'K_Mobil',
       'K_Motor', 'Lainnya', 'Kategori'], how='outer')
Data_Sidorejo = pd.merge(Data_Sidorejo, SidorejoRT03, on=['Nama_Ayah', 'TTL_Ayah', 'Pekerjaan_Ayah', 'Pendidikan_Ayah',
       'Nama_Ibu', 'TTL_Ibu', 'Pekerjaan_Ibu', 'Pendidikan_Ibu', 'Nama_Anak1',
       'TTL_Anak1', 'Pekerjaan_Anak1', 'Pendidikan_Anak1', 'Nama_Anak2',
       'TTL_Anak2', 'Pekerjaan_Anak2', 'Pendidikan_Anak2', 'Nama_Anak3',
       'TTL_Anak3', 'Pekerjaan_Anak3', 'Pendidikan_Anak3', 'Nama_Anak4',
       'TTL_Anak4', 'Pekerjaan_Anak4', 'Pendidikan_Anak4', 'RT_MilikSendiri',
       'RT_IkutOrangTua', 'RT_Kontrak', 'Tanah_Sawah', 'Tanah_Kebun',
       'HT_Sapi', 'HT_Kambing', 'HT_Ayam', 'HT_Bebek', 'HT_Lele', 'K_Mobil',
       'K_Motor', 'Lainnya', 'Kategori'], how='outer')

# %%
Data_Sidorejo.head(1)
# Out:
#       Nama_Ayah                   TTL_Ayah Pekerjaan_Ayah Pendidikan_Ayah  \
# 0  MOCH ZARKASI  PONOROGO, 05 AGUSTUS 1948      PENSIUNAN               -
#
#    Nama_Ibu                     TTL_Ibu Pekerjaan_Ibu Pendidikan_Ibu  \
# 0  MASNUNAH  PONOROGO, 31 DESEMBER 1956     PENSIUNAN             S1
#
#        Nama_Anak1              TTL_Anak1  ... Tanah_Kebun HT_Sapi HT_Kambing  \
# 0  EVA HENDRAWATI  PONOROGO, 29 MEI 1978  ...           √     NaN        NaN
#
#   HT_Ayam HT_Bebek HT_Lele K_Mobil K_Motor Lainnya   Kategori
# 0       √      NaN       √       √       √     NaN  SEJAHTERA
#
# [1 rows x 38 columns]

# %% [markdown]
# ### TOTAL DATA

# %%
Data_Sidorejo.shape
# Out:
# (143, 38)

# %% [markdown]
# ## DUSUN JASEM

# %% [markdown]
# ### RT01

# %%
JasemRT01 = pd.read_excel('ProyekDesa_Sedah/RekapSurveySensusDesaSedah/K22_JASEM/RekapSurveySensus_K22.xlsx', sheet_name='RT 01')
JasemRT01 = JasemRT01.iloc[5:]
JasemRT01 = JasemRT01.drop(JasemRT01.columns[0], axis=1)
JasemRT01.head(1)
# Out:
#      Unnamed: 1                 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 5  MOCH ZARKASI  PONOROGO, 05 AGUSTUS 1948  PENSIUNAN          -   MASNUNAH
#
#                    Unnamed: 6 Unnamed: 7 Unnamed: 8      Unnamed: 9  \
# 5  PONOROGO, 31 DESEMBER 1956  PENSIUNAN         S1  EVA HENDRAWATI
#
#              Unnamed: 10  ... Unnamed: 29 Unnamed: 30 Unnamed: 31 Unnamed: 32  \
# 5  PONOROGO, 29 MEI 1978  ...           √         NaN         NaN           √
#
#   Unnamed: 33 Unnamed: 34 Unnamed: 35 Unnamed: 36 Unnamed: 37 Unnamed: 38
# 5         NaN           √           √           √         NaN   SEJAHTERA
#
# [1 rows x 38 columns]

# %% [markdown]
# ### RT02

# %% [markdown]
# ### RT03
