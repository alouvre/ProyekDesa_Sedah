# %% [markdown]
# <a href="https://colab.research.google.com/github/alouvre/ProyekDesa_Sedah/blob/main/ProyekDesa_SensusDesaSedah.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/alouvre/ProyekDesa_Sedah.git/

# %%
import pandas as pd
import plotly.express as px
import seaborn as sns
import matplotlib.pyplot as plt

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %% [markdown]
# # **COLLECTING DATA**

# %% [markdown]
# ## DUSUN KRAJAN - AMAN

# %% [markdown]
# ### RT01 - AMAN

# %%
KrajanRT01 = pd.read_excel('ProyekDesa_Sedah/RekapSurveySensusDesaSedah/K20_KRAJAN/DATA PENDUDUK DUSUN SIDOREJO RT 01^J 02^J 03 KRAJAN RT 1,RT 2, RT 3 FIXX.xlsx', sheet_name='RT 1')
KrajanRT01 = KrajanRT01.iloc[5:]
KrajanRT01 = KrajanRT01.drop(KrajanRT01.columns[0], axis=1)
KrajanRT01.head(1)
# Out:
#   Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4     Unnamed: 5 Unnamed: 6  \
# 5  ALI IMRON        NaN     TUKANG        SMA  SITI ANJARIAH        NaN
#
#   Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11 Unnamed: 12  \
# 5       GURU         S1        NaN         NaN         NaN          S1
#
#   Unnamed: 13 Unnamed: 14 Unnamed: 15 Unnamed: 16 Unnamed: 17 Unnamed: 18  \
# 5         NaN         NaN         NaN         SMA         NaN         NaN
#
#   Unnamed: 19 Unnamed: 20 Unnamed: 21 Unnamed: 22 Unnamed: 23 Unnamed: 24  \
# 5         NaN          SD         NaN         NaN         NaN         NaN
#
#   Unnamed: 25 Unnamed: 26 Unnamed: 27 Unnamed: 28 Unnamed: 29 Unnamed: 30  \
# 5           √         NaN         NaN           √         NaN         NaN
#
#   Unnamed: 31 Unnamed: 32 Unnamed: 33 Unnamed: 34 Unnamed: 35 Unnamed: 36  \
# 5         NaN           √         NaN         NaN         NaN         NaN
#
#   Unnamed: 37 Unnamed: 38
# 5         NaN    MENENGAH

# %%
KrajanRT01.columns = ['Nama_Ayah', 'TTL_Ayah', 'Pekerjaan_Ayah', 'Pendidikan_Ayah',
                    'Nama_Ibu', 'TTL_Ibu', 'Pekerjaan_Ibu', 'Pendidikan_Ibu',
                    'Nama_Anak1', 'TTL_Anak1', 'Pekerjaan_Anak1', 'Pendidikan_Anak1',
                    'Nama_Anak2', 'TTL_Anak2', 'Pekerjaan_Anak2', 'Pendidikan_Anak2',
                    'Nama_Anak3', 'TTL_Anak3', 'Pekerjaan_Anak3', 'Pendidikan_Anak3',
                    'Nama_Anak4', 'TTL_Anak4', 'Pekerjaan_Anak4', 'Pendidikan_Anak4',
                    'RT_MilikSendiri', 'RT_IkutOrangTua', 'RT_Kontrak',
                    'Tanah_Sawah', 'Tanah_Kebun',
                    'HT_Sapi', 'HT_Kambing', 'HT_Ayam', 'HT_Bebek', 'HT_Lele',
                    'K_Mobil', 'K_Motor', 'Lainnya', 'Kategori'
                    ]

# %%
# DROP INDEKS 54-61
KrajanRT01 = KrajanRT01.drop(list(range(54,61)))

# %%
KrajanRT01.head(57)
# Out:
#                   Nama_Ayah   TTL_Ayah       Pekerjaan_Ayah   Pendidikan_Ayah  \
# 5                 ALI IMRON        NaN               TUKANG               SMA
# 6                   SUMANTO        NaN           BURUH TANI               SMP
# 7         ARIF WAHYU WIDODO        NaN  PEGAWAI RUMAH SAKIT               SMA
# 8                   KADIMUN        NaN               TUKANG               SMA
# 9                     SAKRI        NaN               PETANI                SD
# 10                  MULYOTO        NaN           BURUH TANI                SD
# 11                      NaN        NaN                  NaN               NaN
# 12                  SUKARNO        NaN           BURUH TANI                SD
# 13                   KUSNAN        NaN           KONTRAKTOR                SD
# 14      ARIZKY RAGIL ANDYKA        NaN            PENGUSAHA              SLTA
# 15                      NaN        NaN                  NaN               NaN
# ...

# %%
KrajanRT01.shape
# Out:
# (50, 38)

# %% [markdown]
# ### RT02 - AMAN

# %%
KrajanRT02 = pd.read_excel('ProyekDesa_Sedah/RekapSurveySensusDesaSedah/K20_KRAJAN/DATA PENDUDUK DUSUN SIDOREJO RT 01^J 02^J 03 KRAJAN RT 1,RT 2, RT 3 FIXX.xlsx', sheet_name='RT 2')
KrajanRT02 = KrajanRT02.iloc[5:]
KrajanRT02 = KrajanRT02.drop(KrajanRT02.columns[0], axis=1)
KrajanRT02.head(1)
# Out:
#       Unnamed: 1 Unnamed: 2   Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 5  LUKMAN EFENDI        NaN  KEPALA DESA       S1          NaN        NaN
#
#   Unnamed: 7 Unnamed: 8       Unnamed: 9 Unnamed: 10 Unnamed: 11 Unnamed: 12  \
# 5        NaN        NaN  MUHAMMAD  HARIR         NaN         NaN          SD
#
#              Unnamed: 13 Unnamed: 14 Unnamed: 15 Unnamed: 16 Unnamed: 17  \
# 5  AHMAD  MUSTOFA EFENDI         NaN         NaN          SD         NaN
#
#   Unnamed: 18 Unnamed: 19 Unnamed: 20 Unnamed: 21 Unnamed: 22 Unnamed: 23  \
# 5         NaN         NaN         NaN         NaN         NaN         NaN
#
#   Unnamed: 24 Unnamed: 25 Unnamed: 26 Unnamed: 27 Unnamed: 28 Unnamed: 29  \
# 5         NaN           √         NaN         NaN           √         NaN
#
#   Unnamed: 30 Unnamed: 31 Unnamed: 32 Unnamed: 33 Unnamed: 34 Unnamed: 35  \
# 5         NaN         NaN           √         NaN         NaN         NaN
#
#   Unnamed: 36 Unnamed: 37 Unnamed: 38
# ...

# %%
KrajanRT02.columns = ['Nama_Ayah', 'TTL_Ayah', 'Pekerjaan_Ayah', 'Pendidikan_Ayah',
                    'Nama_Ibu', 'TTL_Ibu', 'Pekerjaan_Ibu', 'Pendidikan_Ibu',
                    'Nama_Anak1', 'TTL_Anak1', 'Pekerjaan_Anak1', 'Pendidikan_Anak1',
                    'Nama_Anak2', 'TTL_Anak2', 'Pekerjaan_Anak2', 'Pendidikan_Anak2',
                    'Nama_Anak3', 'TTL_Anak3', 'Pekerjaan_Anak3', 'Pendidikan_Anak3',
                    'Nama_Anak4', 'TTL_Anak4', 'Pekerjaan_Anak4', 'Pendidikan_Anak4',
                    'RT_MilikSendiri', 'RT_IkutOrangTua', 'RT_Kontrak',
                    'Tanah_Sawah', 'Tanah_Kebun',
                    'HT_Sapi', 'HT_Kambing', 'HT_Ayam', 'HT_Bebek', 'HT_Lele',
                    'K_Mobil', 'K_Motor', 'Lainnya', 'Kategori'
                    ]

# %%
# DROP INDEKS 36-59
KrajanRT02 = KrajanRT02.drop(list(range(36,60)))

# %%
KrajanRT02.head(55)
# Out:
#           Nama_Ayah TTL_Ayah Pekerjaan_Ayah Pendidikan_Ayah  \
# 5     LUKMAN EFENDI      NaN    KEPALA DESA            S1
# 6               NaN      NaN            NaN             NaN
# 7      JOKO PURNOMO      NaN         PETANI            SLTA
# 8            CHABIB      NaN         SWASTA            S1
# 9          ZAINURI       NaN            PNS            S1
# 10              NaN      NaN            NaN             NaN
# 11           SAKUR       NaN            NaN            SLTA
# 12       SYAFRUDDIN      NaN            PNS            S1
# 13   G. TRI WAHYONO      NaN          BPBD             S1
# 14        SUGIYANTO      NaN   BURUH PABRIK              SD
# 15              NaN      NaN            NaN             NaN
# 16     AHMAD KENIDI      NaN     WIRASWASTA             SMA
# 17              NaN      NaN            NaN             NaN
# 18              NaN      NaN            NaN             NaN
# 19     ACHMAD RIJAL      NaN     WIRASWASTA            S1
# ...

# %%
KrajanRT02.shape
# Out:
# (31, 38)

# %% [markdown]
# ### RT03 - AMAN

# %%
KrajanRT03 = pd.read_excel('ProyekDesa_Sedah/RekapSurveySensusDesaSedah/K20_KRAJAN/DATA PENDUDUK DUSUN SIDOREJO RT 01^J 02^J 03 KRAJAN RT 1,RT 2, RT 3 FIXX.xlsx', sheet_name='RT 3')
KrajanRT03 = KrajanRT03.iloc[5:]
KrajanRT03 = KrajanRT03.drop(KrajanRT03.columns[0], axis=1)
KrajanRT03.head(1)
# Out:
#   Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 5    KADIRAN        NaN     PETANI          -   MURIANA         NaN
#
#   Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11 Unnamed: 12  \
# 5     PETANI        SD'        NaN         NaN         NaN         NaN
#
#   Unnamed: 13 Unnamed: 14 Unnamed: 15 Unnamed: 16 Unnamed: 17 Unnamed: 18  \
# 5         NaN         NaN         NaN         NaN         NaN         NaN
#
#   Unnamed: 19 Unnamed: 20 Unnamed: 21 Unnamed: 22 Unnamed: 23 Unnamed: 24  \
# 5         NaN         NaN         NaN         NaN         NaN         NaN
#
#   Unnamed: 25 Unnamed: 26 Unnamed: 27 Unnamed: 28 Unnamed: 29 Unnamed: 30  \
# 5           √         NaN         NaN           √         NaN         NaN
#
#   Unnamed: 31 Unnamed: 32 Unnamed: 33 Unnamed: 34 Unnamed: 35 Unnamed: 36  \
# 5         NaN         NaN         NaN         NaN         NaN         NaN
#
#   Unnamed: 37 Unnamed: 38
# 5         NaN    MENENGAH

# %%
KrajanRT03.columns = ['Nama_Ayah', 'TTL_Ayah', 'Pekerjaan_Ayah', 'Pendidikan_Ayah',
                    'Nama_Ibu', 'TTL_Ibu', 'Pekerjaan_Ibu', 'Pendidikan_Ibu',
                    'Nama_Anak1', 'TTL_Anak1', 'Pekerjaan_Anak1', 'Pendidikan_Anak1',
                    'Nama_Anak2', 'TTL_Anak2', 'Pekerjaan_Anak2', 'Pendidikan_Anak2',
                    'Nama_Anak3', 'TTL_Anak3', 'Pekerjaan_Anak3', 'Pendidikan_Anak3',
                    'Nama_Anak4', 'TTL_Anak4', 'Pekerjaan_Anak4', 'Pendidikan_Anak4',
                    'RT_MilikSendiri', 'RT_IkutOrangTua', 'RT_Kontrak',
                    'Tanah_Sawah', 'Tanah_Kebun',
                    'HT_Sapi', 'HT_Kambing', 'HT_Ayam', 'HT_Bebek', 'HT_Lele',
                    'K_Mobil', 'K_Motor', 'Lainnya', 'Kategori'
                    ]

# %%
# DROP INDEKS 40-59
KrajanRT03 = KrajanRT03.drop(list(range(40,60)))

# %%
KrajanRT03.head(55)
# Out:
#             Nama_Ayah TTL_Ayah  \
# 5             KADIRAN      NaN
# 6              MISMAN      NaN
# 7        DANU ASMARA       NaN
# 8      PUGUH SANTOSO       NaN
# 9                 NaN      NaN
# 10             BASUNI      NaN
# 11            SUWANDI      NaN
# 12            SUTIKNO      NaN
# 13    TRIO HERWINSYAH      NaN
# 14           MISKANTO      NaN
# 15             MUSIN       NaN
# 16           HARIYONO      NaN
# 17             SUBANI      NaN
# 18      ZAMRONI YUSUF      NaN
# 19             SUGENG      NaN
# 20  MUHAMMAD ROSYIDIN      NaN
# 21     RIDWAN MUSTAFA      NaN
# 22             SUWITO      NaN
# 23         RENI  ANTO      NaN
# 24                NaN      NaN
# 25      HERI KUSWANTO      NaN
# 26         SYAMSYUDIN      NaN
# 27             SUROTO      NaN
# 28       AHMAD DAROJI      NaN
# 29            SAMSURI      NaN
# 30         AGUS YANTO      NaN
# 31            MARZUKI      NaN
# 32    SUGENG HARIANTO      NaN
# 33      AHMAD SUNARYO      NaN
# ...

# %%
KrajanRT03.shape
# Out:
# (35, 38)

# %% [markdown]
# ### MERGE RT 1 2 3

# %%
Data_Krajan = pd.merge(KrajanRT01, KrajanRT02, on=['Nama_Ayah', 'TTL_Ayah', 'Pekerjaan_Ayah', 'Pendidikan_Ayah',
       'Nama_Ibu', 'TTL_Ibu', 'Pekerjaan_Ibu', 'Pendidikan_Ibu', 'Nama_Anak1',
       'TTL_Anak1', 'Pekerjaan_Anak1', 'Pendidikan_Anak1', 'Nama_Anak2',
       'TTL_Anak2', 'Pekerjaan_Anak2', 'Pendidikan_Anak2', 'Nama_Anak3',
       'TTL_Anak3', 'Pekerjaan_Anak3', 'Pendidikan_Anak3', 'Nama_Anak4',
       'TTL_Anak4', 'Pekerjaan_Anak4', 'Pendidikan_Anak4', 'RT_MilikSendiri',
       'RT_IkutOrangTua', 'RT_Kontrak', 'Tanah_Sawah', 'Tanah_Kebun',
       'HT_Sapi', 'HT_Kambing', 'HT_Ayam', 'HT_Bebek', 'HT_Lele', 'K_Mobil',
       'K_Motor', 'Lainnya', 'Kategori'], how='outer')
Data_Krajan = pd.merge(Data_Krajan, KrajanRT03, on=['Nama_Ayah', 'TTL_Ayah', 'Pekerjaan_Ayah', 'Pendidikan_Ayah',
       'Nama_Ibu', 'TTL_Ibu', 'Pekerjaan_Ibu', 'Pendidikan_Ibu', 'Nama_Anak1',
       'TTL_Anak1', 'Pekerjaan_Anak1', 'Pendidikan_Anak1', 'Nama_Anak2',
       'TTL_Anak2', 'Pekerjaan_Anak2', 'Pendidikan_Anak2', 'Nama_Anak3',
       'TTL_Anak3', 'Pekerjaan_Anak3', 'Pendidikan_Anak3', 'Nama_Anak4',
       'TTL_Anak4', 'Pekerjaan_Anak4', 'Pendidikan_Anak4', 'RT_MilikSendiri',
       'RT_IkutOrangTua', 'RT_Kontrak', 'Tanah_Sawah', 'Tanah_Kebun',
       'HT_Sapi', 'HT_Kambing', 'HT_Ayam', 'HT_Bebek', 'HT_Lele', 'K_Mobil',
       'K_Motor', 'Lainnya', 'Kategori'], how='outer')
# Out:
# <ipython-input-1305-fa3ce8b0b350>:1: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   Data_Krajan = pd.merge(KrajanRT01, KrajanRT02, on=['Nama_Ayah', 'TTL_Ayah', 'Pekerjaan_Ayah', 'Pendidikan_Ayah',
# <ipython-input-1305-fa3ce8b0b350>:1: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   Data_Krajan = pd.merge(KrajanRT01, KrajanRT02, on=['Nama_Ayah', 'TTL_Ayah', 'Pekerjaan_Ayah', 'Pendidikan_Ayah',
# <ipython-input-1305-fa3ce8b0b350>:1: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   Data_Krajan = pd.merge(KrajanRT01, KrajanRT02, on=['Nama_Ayah', 'TTL_Ayah', 'Pekerjaan_Ayah', 'Pendidikan_Ayah',
# ...

# %%
Data_Krajan['Pekerjaan_Ibu']
# Out:
# 0             GURU
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# 5              NaN
# 6        IBU RUMAH
# 7              NaN
# 8              NaN
# 9              NaN
# 10       IBU RUMAH
# 11             NaN
# 12             NaN
# 13             NaN
# 14             NaN
# 15             NaN
# 16             NaN
# 17             NaN
# 18       IBU RUMAH
# 19             NaN
# 20             NaN
# 21             NaN
# 22             NaN
# 23             NaN
# 24             NaN
# 25             NaN
# 26             NaN
# 27             NaN
# 28             NaN
# 29       IBU RUMAH
# 30             NaN
# 31             NaN
# 32             NaN
# 33             NaN
# 34             NaN
# 35             NaN
# 36          PETANI
# 37             NaN
# 38             NaN
# 39             IRT
# 40             NaN
# 41      BURUH TANI
# 42             IRT
# 43             NaN
# 44          PETANI
# 45             IRT
# 46             IRT
# ...

# %%
# Menyimpan DataFrame ke dalam file Excel
nama_file_excel = 'data_penduduk_dusun_krajan.xlsx'
Data_Krajan.to_excel(nama_file_excel, index=False)

# %%
Data_Krajan = Data_Krajan[['Nama_Ayah', 'Pekerjaan_Ayah', 'Pendidikan_Ayah','Kategori']]
Data_Krajan.columns = ['Nama', 'Pekerjaan', 'Pendidikan', 'Kategori']

# %%
LabelKategori = {'PRA  SEJAHTERA': 'PRASEJAHTERA'}
Data_Krajan['Kategori'] = Data_Krajan['Kategori'].replace(LabelKategori)
# Out:
# <ipython-input-1309-0e7d294b2cb0>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Data_Krajan['Kategori'] = Data_Krajan['Kategori'].replace(LabelKategori)

# %%
Data_Krajan['Kategori'].value_counts()
# Out:
# MENENGAH        90
# SEJAHTERA       22
# PRASEJAHTERA     3
# Name: Kategori, dtype: int64

# %% [markdown]
# ### TOTAL DATA

# %%
# Mengisi nilai pada beberapa indeks dan kolom
indeks_yang_akan_diisi = [6, 10, 18, 29, 36, 39, 41, 45, 46, 51, 55, 60, 62, 63, 66, 69, 71, 72, 76, 77, 85, 100]
nilai_nama_yang_akan_diisi = ['MESIJAH', 'KAYATI', 'SUTIRAH', 'WAKHIDATUL', 'BINTI KHORIYAH', 'DARNING TUTIEK', 'NANIK ISMIYATI',
                              'SUKILAH', 'SIYEM', 'MUTMAINAH', 'HARTINAH', 'NURHAYATI', 'SAMINEM', 'MUBAYANAH', 'SUMARTI', 'ENDANG',
                              'SITI MASRUROH', 'ENY ANALIYA', 'SRINGATUN', 'SAMSIAH', 'SITI ROKHMATIN', 'SUMINI']
nilai_pekerjaan_yang_akan_diisi = ['IRT', 'IRT', 'IRT', 'IRT', 'PETANI', 'IRT', 'BURUH TANI', 'IRT', 'IRT', 'WIRASWASTA', 'BURUH TANI', 'IRT', 'PETANI', 'IRT',
                                   'IRT', 'PNS', 'PENSIUN PNS', 'WIRASWASTA', 'IRT', 'IRT', 'SERABUTAN', 'IRT']
nilai_pendidikan_yang_akan_diisi = ['-', '-', 'SD', 'SLTP', 'SMP', 'SLTA', '-', '-', '-', '-', 'SD', 'SD', 'SD', 'SD', 'SD', 'S1',
                                    'SMA', 'SLTA', 'SD', 'SD', 'SD', 'SD']

# Menggunakan metode at atau loc untuk setiap kolom dan indeks
for indeks, nama, pekerjaan, pendidikan in zip(indeks_yang_akan_diisi, nilai_nama_yang_akan_diisi, nilai_pekerjaan_yang_akan_diisi, nilai_pendidikan_yang_akan_diisi):
    Data_Krajan.loc[indeks, 'Nama'] = nama
    Data_Krajan.loc[indeks, 'Pekerjaan'] = pekerjaan
    Data_Krajan.loc[indeks, 'Pendidikan'] = pendidikan

# %%
Data_Krajan = Data_Krajan.drop(49)
Data_Krajan = Data_Krajan.reset_index(drop=True)

# %%
Data_Krajan
# Out:
#                         Nama  \
# 0                  ALI IMRON
# 1                    SUMANTO
# 2          ARIF WAHYU WIDODO
# 3                    KADIMUN
# 4                      SAKRI
# 5                    MULYOTO
# 6                    MESIJAH
# 7                    SUKARNO
# 8                     KUSNAN
# 9        ARIZKY RAGIL ANDYKA
# 10                    KAYATI
# 11                   KATIMUN
# 12                BASHIRUDIN
# 13                   PURNOMO
# 14                SUPRIYANTO
# 15                USMAN HADI
# 16            HERU NOVIYANTO
# 17                    JIKUN
# 18                   SUTIRAH
# 19              JOKO SUYITNO
# 20                   SARJUNI
# 21          RYHAN WARA ADI K
# 22                    SUYADI
# 23              ARJO MESERAN
# 24                    SUYOTO
# 25                    SUMALI
# 26                TRI ATMONO
# 27                     SARNI
# 28                     SARDO
# 29                WAKHIDATUL
# 30           ANANG FADHILAH
# ...

# %%
Data_Krajan.shape
# Out:
# (115, 4)

# %% [markdown]
# ## DUSUN SIDOREJO - AMAN

# %% [markdown]
# ### RT01 - AMAN

# %%
SidorejoRT01 = pd.read_excel('ProyekDesa_Sedah/RekapSurveySensusDesaSedah/K21_SIDOREJO/DATA PENDUDUK DUSUN SIDOREJO RT 01, 02, 03.xlsx', sheet_name='RT 01')
SidorejoRT01 = SidorejoRT01.iloc[5:]
SidorejoRT01 = SidorejoRT01.drop(SidorejoRT01.columns[0], axis=1)
SidorejoRT01.head(1)
# Out:
#      Unnamed: 1                 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 5  MOCH ZARKASI  PONOROGO, 05 AGUSTUS 1948  PENSIUNAN          -   MASNUNAH
#
#                    Unnamed: 6 Unnamed: 7 Unnamed: 8      Unnamed: 9  \
# 5  PONOROGO, 31 DESEMBER 1956  PENSIUNAN         S1  EVA HENDRAWATI
#
#              Unnamed: 10 Unnamed: 11 Unnamed: 12 Unnamed: 13 Unnamed: 14  \
# 5  PONOROGO, 29 MEI 1978           -           -         NaN         NaN
#
#   Unnamed: 15 Unnamed: 16 Unnamed: 17 Unnamed: 18 Unnamed: 19 Unnamed: 20  \
# 5         NaN         NaN         NaN         NaN         NaN         NaN
#
#             Unnamed: 21              Unnamed: 22 Unnamed: 23 Unnamed: 24  \
# 5  SETYAWAN ASRUL FUADA  PONOROGO, 13 MARET 1990        GURU          S1
#
#   Unnamed: 25 Unnamed: 26 Unnamed: 27 Unnamed: 28 Unnamed: 29 Unnamed: 30  \
# 5           √         NaN         NaN           √           √         NaN
#
# ...

# %%
SidorejoRT01.columns = ['Nama_Ayah', 'TTL_Ayah', 'Pekerjaan_Ayah', 'Pendidikan_Ayah',
                    'Nama_Ibu', 'TTL_Ibu', 'Pekerjaan_Ibu', 'Pendidikan_Ibu',
                    'Nama_Anak1', 'TTL_Anak1', 'Pekerjaan_Anak1', 'Pendidikan_Anak1',
                    'Nama_Anak2', 'TTL_Anak2', 'Pekerjaan_Anak2', 'Pendidikan_Anak2',
                    'Nama_Anak3', 'TTL_Anak3', 'Pekerjaan_Anak3', 'Pendidikan_Anak3',
                    'Nama_Anak4', 'TTL_Anak4', 'Pekerjaan_Anak4', 'Pendidikan_Anak4',
                    'RT_MilikSendiri', 'RT_IkutOrangTua', 'RT_Kontrak',
                    'Tanah_Sawah', 'Tanah_Kebun',
                    'HT_Sapi', 'HT_Kambing', 'HT_Ayam', 'HT_Bebek', 'HT_Lele',
                    'K_Mobil', 'K_Motor', 'Lainnya', 'Kategori'
                    ]

# %%
SidorejoRT01.head(1)
# AMAN
# Out:
#       Nama_Ayah                   TTL_Ayah Pekerjaan_Ayah Pendidikan_Ayah  \
# 5  MOCH ZARKASI  PONOROGO, 05 AGUSTUS 1948      PENSIUNAN               -
#
#    Nama_Ibu                     TTL_Ibu Pekerjaan_Ibu Pendidikan_Ibu  \
# 5  MASNUNAH  PONOROGO, 31 DESEMBER 1956     PENSIUNAN             S1
#
#        Nama_Anak1              TTL_Anak1 Pekerjaan_Anak1 Pendidikan_Anak1  \
# 5  EVA HENDRAWATI  PONOROGO, 29 MEI 1978               -                -
#
#   Nama_Anak2 TTL_Anak2 Pekerjaan_Anak2 Pendidikan_Anak2 Nama_Anak3 TTL_Anak3  \
# 5        NaN       NaN             NaN              NaN        NaN       NaN
#
#   Pekerjaan_Anak3 Pendidikan_Anak3            Nama_Anak4  \
# 5             NaN              NaN  SETYAWAN ASRUL FUADA
#
#                  TTL_Anak4 Pekerjaan_Anak4 Pendidikan_Anak4 RT_MilikSendiri  \
# 5  PONOROGO, 13 MARET 1990            GURU               S1               √
#
#   RT_IkutOrangTua RT_Kontrak Tanah_Sawah Tanah_Kebun HT_Sapi HT_Kambing  \
# ...

# %%
SidorejoRT01.shape
# Out:
# (39, 38)

# %% [markdown]
# ### RT02 - AMAN

# %%
SidorejoRT02 = pd.read_excel('ProyekDesa_Sedah/RekapSurveySensusDesaSedah/K21_SIDOREJO/DATA PENDUDUK DUSUN SIDOREJO RT 01, 02, 03.xlsx', sheet_name='RT 02')
SidorejoRT02 = SidorejoRT02.iloc[5:]
SidorejoRT02 = SidorejoRT02.drop(SidorejoRT02.columns[0], axis=1)
SidorejoRT02.head(1)
# Out:
#          Unnamed: 1                  Unnamed: 2    Unnamed: 3 Unnamed: 4  \
# 5  Adi Marga Susila  Ponorogo, 18 Desember 1965  Pengangguran         S1
#
#   Unnamed: 5                   Unnamed: 6        Unnamed: 7 Unnamed: 8  \
# 5    Purwati  Bojonegoro, 17 Agustus 1965  Ibu Rumah Tangga        SMP
#
#              Unnamed: 9              Unnamed: 10 Unnamed: 11 Unnamed: 12  \
# 5  Wahyu Ghany Abdullah  Madiun, 24 Oktober 1997      Swasta         SMK
#
#   Unnamed: 13 Unnamed: 14 Unnamed: 15 Unnamed: 16 Unnamed: 17 Unnamed: 18  \
# 5         NaN         NaN         NaN         NaN         NaN         NaN
#
#   Unnamed: 19 Unnamed: 20 Unnamed: 21 Unnamed: 22 Unnamed: 23 Unnamed: 24  \
# 5         NaN         NaN         NaN         NaN         NaN         NaN
#
#   Unnamed: 25 Unnamed: 26 Unnamed: 27 Unnamed: 28 Unnamed: 29 Unnamed: 30  \
# 5           √         NaN         NaN         NaN         NaN         NaN
#
# ...

# %%
SidorejoRT02.columns = ['Nama_Ayah', 'TTL_Ayah', 'Pekerjaan_Ayah', 'Pendidikan_Ayah',
                    'Nama_Ibu', 'TTL_Ibu', 'Pekerjaan_Ibu', 'Pendidikan_Ibu',
                    'Nama_Anak1', 'TTL_Anak1', 'Pekerjaan_Anak1', 'Pendidikan_Anak1',
                    'Nama_Anak2', 'TTL_Anak2', 'Pekerjaan_Anak2', 'Pendidikan_Anak2',
                    'Nama_Anak3', 'TTL_Anak3', 'Pekerjaan_Anak3', 'Pendidikan_Anak3',
                    'Nama_Anak4', 'TTL_Anak4', 'Pekerjaan_Anak4', 'Pendidikan_Anak4',
                    'RT_MilikSendiri', 'RT_IkutOrangTua', 'RT_Kontrak',
                    'Tanah_Sawah', 'Tanah_Kebun',
                    'HT_Sapi', 'HT_Kambing', 'HT_Ayam', 'HT_Bebek', 'HT_Lele',
                    'K_Mobil', 'K_Motor', 'Lainnya', 'Kategori'
                    ]

# %%
# DROP INDEKS 47-59
SidorejoRT02 = SidorejoRT02.drop(list(range(47,60)))

# %%
SidorejoRT02.head(42)
# Out:
#               Nama_Ayah                     TTL_Ayah  Pekerjaan_Ayah  \
# 5      Adi Marga Susila   Ponorogo, 18 Desember 1965    Pengangguran
# 6                   NaN                          NaN             NaN
# 7                   NaN                          NaN             NaN
# 8    Muchlas Bin Romlah       Ponorogo, 5 Maret 1949       Pensiunan
# 9    Much Bahrun Amrozi  Ponorogo, 11 September 1974          Swasta
# 10         Zen Suprapto       Ponorogo, 3 April 1968          Petani
# 11                  NaN                          NaN             NaN
# 12         Lukman Fajar        Ponorogo, 27 Mei 1971      Wiraswasta
# 13              Suharto                          NaN          Petani
# 14                  NaN                          NaN             NaN
# 15   Samingan Suprianto      Ponorogo, 13 Maret 1957      Wiraswasta
# 16       Habib Musta'an      Ponorogo, 13 Maret 1989             PNS
# 17                  NaN                          NaN             NaN
# ...

# %%
SidorejoRT02.shape
# Out:
# (42, 38)

# %% [markdown]
# ### RT03 - AMAN

# %%
SidorejoRT03 = pd.read_excel('ProyekDesa_Sedah/RekapSurveySensusDesaSedah/K21_SIDOREJO/DATA PENDUDUK DUSUN SIDOREJO RT 01, 02, 03.xlsx', sheet_name='RT 03')
SidorejoRT03 = SidorejoRT03.iloc[5:]
SidorejoRT03 = SidorejoRT03.drop(SidorejoRT03.columns[0], axis=1)
SidorejoRT03.head(1)
# Out:
#   Unnamed: 1                  Unnamed: 2  Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 5   SUPRIADI  PONOROGO, 16 FEBRUARI 1973  WIRASWASTA       SLTP    MURYATI
#
#                   Unnamed: 6  Unnamed: 7 Unnamed: 8           Unnamed: 9  \
# 5  PONOROGO, 17 OKTOBER 1980  WIRASWASTA         SD  AISAH PUTRI PRATIWI
#
#                  Unnamed: 10 Unnamed: 11 Unnamed: 12 Unnamed: 13 Unnamed: 14  \
# 5  PONOROGO, 23 OKTOBER 2005     PELAJAR        SLTP           -           -
#
#   Unnamed: 15 Unnamed: 16 Unnamed: 17 Unnamed: 18 Unnamed: 19 Unnamed: 20  \
# 5           -           -           -           -           -           -
#
#   Unnamed: 21 Unnamed: 22 Unnamed: 23 Unnamed: 24 Unnamed: 25 Unnamed: 26  \
# 5           -           -           -           -           √           -
#
#   Unnamed: 27 Unnamed: 28 Unnamed: 29 Unnamed: 30 Unnamed: 31 Unnamed: 32  \
# 5           -           -           -           -           -           -
#
# ...

# %%
SidorejoRT03.columns = ['Nama_Ayah', 'TTL_Ayah', 'Pekerjaan_Ayah', 'Pendidikan_Ayah',
                    'Nama_Ibu', 'TTL_Ibu', 'Pekerjaan_Ibu', 'Pendidikan_Ibu',
                    'Nama_Anak1', 'TTL_Anak1', 'Pekerjaan_Anak1', 'Pendidikan_Anak1',
                    'Nama_Anak2', 'TTL_Anak2', 'Pekerjaan_Anak2', 'Pendidikan_Anak2',
                    'Nama_Anak3', 'TTL_Anak3', 'Pekerjaan_Anak3', 'Pendidikan_Anak3',
                    'Nama_Anak4', 'TTL_Anak4', 'Pekerjaan_Anak4', 'Pendidikan_Anak4',
                    'RT_MilikSendiri', 'RT_IkutOrangTua', 'RT_Kontrak',
                    'Tanah_Sawah', 'Tanah_Kebun',
                    'HT_Sapi', 'HT_Kambing', 'HT_Ayam', 'HT_Bebek', 'HT_Lele',
                    'K_Mobil', 'K_Motor', 'Lainnya', 'Kategori'
                    ]

# %%
SidorejoRT03.head(49)
# AMAN
# Out:
#                    Nama_Ayah                     TTL_Ayah      Pekerjaan_Ayah  \
# 5                   SUPRIADI   PONOROGO, 16 FEBRUARI 1973          WIRASWASTA
# 6              IMRON ZUBAIDI       PONOROGO, 29 JULI 1977          WIRASWASTA
# 7              SUGENG RIYADI     KEDIRI, 30 NOVEMBER 1970              SWASTA
# 8              ALM. MUHTAROM                            -                   -
# 9   FAIZ FARUKI AL-KHUDZAIFI    PONOROGO, 12 AGUSTUS 1994              SWASTA
# 10                   MUZAYIN      PONOROGO, 26 MARET 1969                TANI
# 11               ABDUL MANAF         MADIUN, 7 MARET 1979     KARYAWAN SWASTA
# 12                         -                            -                   -
# 13                  MUSTAJAB        PONOROGO, 30 MEI 1957                TANI
# 14             FANANI AFANDI   PONOROGO, 24 NOVEMBER 1968              SWASTA
# 15                    FUDOLI        PONOROGO, 23 DESEMBER               SOPIR
# ...

# %%
SidorejoRT03.shape
# Out:
# (49, 38)

# %% [markdown]
# ### MERGE RT 1 2 3

# %%
SidorejoRT01.columns
# Out:
# Index(['Nama_Ayah', 'TTL_Ayah', 'Pekerjaan_Ayah', 'Pendidikan_Ayah',
#        'Nama_Ibu', 'TTL_Ibu', 'Pekerjaan_Ibu', 'Pendidikan_Ibu', 'Nama_Anak1',
#        'TTL_Anak1', 'Pekerjaan_Anak1', 'Pendidikan_Anak1', 'Nama_Anak2',
#        'TTL_Anak2', 'Pekerjaan_Anak2', 'Pendidikan_Anak2', 'Nama_Anak3',
#        'TTL_Anak3', 'Pekerjaan_Anak3', 'Pendidikan_Anak3', 'Nama_Anak4',
#        'TTL_Anak4', 'Pekerjaan_Anak4', 'Pendidikan_Anak4', 'RT_MilikSendiri',
#        'RT_IkutOrangTua', 'RT_Kontrak', 'Tanah_Sawah', 'Tanah_Kebun',
#        'HT_Sapi', 'HT_Kambing', 'HT_Ayam', 'HT_Bebek', 'HT_Lele', 'K_Mobil',
#        'K_Motor', 'Lainnya', 'Kategori'],
#       dtype='object')

# %%
SidorejoRT02.columns
# Out:
# Index(['Nama_Ayah', 'TTL_Ayah', 'Pekerjaan_Ayah', 'Pendidikan_Ayah',
#        'Nama_Ibu', 'TTL_Ibu', 'Pekerjaan_Ibu', 'Pendidikan_Ibu', 'Nama_Anak1',
#        'TTL_Anak1', 'Pekerjaan_Anak1', 'Pendidikan_Anak1', 'Nama_Anak2',
#        'TTL_Anak2', 'Pekerjaan_Anak2', 'Pendidikan_Anak2', 'Nama_Anak3',
#        'TTL_Anak3', 'Pekerjaan_Anak3', 'Pendidikan_Anak3', 'Nama_Anak4',
#        'TTL_Anak4', 'Pekerjaan_Anak4', 'Pendidikan_Anak4', 'RT_MilikSendiri',
#        'RT_IkutOrangTua', 'RT_Kontrak', 'Tanah_Sawah', 'Tanah_Kebun',
#        'HT_Sapi', 'HT_Kambing', 'HT_Ayam', 'HT_Bebek', 'HT_Lele', 'K_Mobil',
#        'K_Motor', 'Lainnya', 'Kategori'],
#       dtype='object')

# %%
SidorejoRT03.columns
# Out:
# Index(['Nama_Ayah', 'TTL_Ayah', 'Pekerjaan_Ayah', 'Pendidikan_Ayah',
#        'Nama_Ibu', 'TTL_Ibu', 'Pekerjaan_Ibu', 'Pendidikan_Ibu', 'Nama_Anak1',
#        'TTL_Anak1', 'Pekerjaan_Anak1', 'Pendidikan_Anak1', 'Nama_Anak2',
#        'TTL_Anak2', 'Pekerjaan_Anak2', 'Pendidikan_Anak2', 'Nama_Anak3',
#        'TTL_Anak3', 'Pekerjaan_Anak3', 'Pendidikan_Anak3', 'Nama_Anak4',
#        'TTL_Anak4', 'Pekerjaan_Anak4', 'Pendidikan_Anak4', 'RT_MilikSendiri',
#        'RT_IkutOrangTua', 'RT_Kontrak', 'Tanah_Sawah', 'Tanah_Kebun',
#        'HT_Sapi', 'HT_Kambing', 'HT_Ayam', 'HT_Bebek', 'HT_Lele', 'K_Mobil',
#        'K_Motor', 'Lainnya', 'Kategori'],
#       dtype='object')

# %%
Data_Sidorejo = pd.merge(SidorejoRT01, SidorejoRT02, on=['Nama_Ayah', 'TTL_Ayah', 'Pekerjaan_Ayah', 'Pendidikan_Ayah',
       'Nama_Ibu', 'TTL_Ibu', 'Pekerjaan_Ibu', 'Pendidikan_Ibu', 'Nama_Anak1',
       'TTL_Anak1', 'Pekerjaan_Anak1', 'Pendidikan_Anak1', 'Nama_Anak2',
       'TTL_Anak2', 'Pekerjaan_Anak2', 'Pendidikan_Anak2', 'Nama_Anak3',
       'TTL_Anak3', 'Pekerjaan_Anak3', 'Pendidikan_Anak3', 'Nama_Anak4',
       'TTL_Anak4', 'Pekerjaan_Anak4', 'Pendidikan_Anak4', 'RT_MilikSendiri',
       'RT_IkutOrangTua', 'RT_Kontrak', 'Tanah_Sawah', 'Tanah_Kebun',
       'HT_Sapi', 'HT_Kambing', 'HT_Ayam', 'HT_Bebek', 'HT_Lele', 'K_Mobil',
       'K_Motor', 'Lainnya', 'Kategori'], how='outer')
Data_Sidorejo = pd.merge(Data_Sidorejo, SidorejoRT03, on=['Nama_Ayah', 'TTL_Ayah', 'Pekerjaan_Ayah', 'Pendidikan_Ayah',
       'Nama_Ibu', 'TTL_Ibu', 'Pekerjaan_Ibu', 'Pendidikan_Ibu', 'Nama_Anak1',
       'TTL_Anak1', 'Pekerjaan_Anak1', 'Pendidikan_Anak1', 'Nama_Anak2',
       'TTL_Anak2', 'Pekerjaan_Anak2', 'Pendidikan_Anak2', 'Nama_Anak3',
       'TTL_Anak3', 'Pekerjaan_Anak3', 'Pendidikan_Anak3', 'Nama_Anak4',
       'TTL_Anak4', 'Pekerjaan_Anak4', 'Pendidikan_Anak4', 'RT_MilikSendiri',
       'RT_IkutOrangTua', 'RT_Kontrak', 'Tanah_Sawah', 'Tanah_Kebun',
       'HT_Sapi', 'HT_Kambing', 'HT_Ayam', 'HT_Bebek', 'HT_Lele', 'K_Mobil',
       'K_Motor', 'Lainnya', 'Kategori'], how='outer')

# %%
Data_Sidorejo['Pendidikan_Ibu']
# Out:
# 0                     S1
# 1      D III KEPERAWATAN
# 2                    SMA
# 3                     SD
# 4               SMP/SLTP
# 5               SMP/SLTP
# 6                    SMA
# 7                    SMA
# 8                   SLTA
# 9               DIPLOMA
# 10              SMP/SLTP
# 11                   NaN
# 12                   SMA
# 13                   SMA
# 14                   SMA
# 15              SMP/SLTP
# 16                    SD
# 17                    SD
# 18                   SMA
# 19              SMP/SLTP
# 20                    S1
# 21                    S1
# 22                    SD
# 23                    S1
# 24                  SLTA
# 25              SMP/SLTP
# 26                   SMA
# 27                  SLTA
# 28                  SLTP
# 29                  SLTP
# 30                   SMP
# 31                    S1
# 32                    S1
# 33                  SLTP
# 34                    S2
# 35                    SD
# 36                    S1
# ...

# %%
# Menyimpan DataFrame ke dalam file Excel
nama_file_excel = 'data_penduduk_dusun_sidorejo.xlsx'
Data_Sidorejo.to_excel(nama_file_excel, index=False)

# %%
Data_Sidorejo = Data_Sidorejo[['Nama_Ayah', 'Pekerjaan_Ayah', 'Pendidikan_Ayah','Kategori']]
Data_Sidorejo.columns = ['Nama', 'Pekerjaan', 'Pendidikan', 'Kategori']

# %%
Data_Sidorejo['Kategori'].value_counts()
# Out:
# MENENGAH        63
# SEJAHTERA       37
# PRASEJAHTERA    30
# Name: Kategori, dtype: int64

# %% [markdown]
# ### TOTAL DATA

# %%
# Mengisi nilai pada beberapa indeks dan kolom
indeks_yang_akan_diisi = [13, 17, 18, 22, 35, 38, 40, 41, 45, 48, 51, 59, 62, 69, 71, 75, 88, 94, 103, 122]
nilai_nama_yang_akan_diisi = ['SITI MAEMUNAH', 'MUSTIKAH', 'SITI MUNAWAROH', 'UMI KALSUM', 'ISTIYAH', 'NENI DAHLIA',  'Tri Murtiningsih',
                              'Mukhofifah', 'Yayuk Istiani', 'Sundusiyah',  'Wiji Astuti', 'Markonah', 'Sikem',  'Nur Jannah',
                              'Sulistyowarni', 'Amanah', 'SUPIYATUN', 'ENI DWI WINARSIH', 'SUKATIN', 'MISTUN']
nilai_pekerjaan_yang_akan_diisi = ['WIRASWASTA', '-', 'PETANI', '-', 'IRT', 'WIRASWASTA', 'Pensiunan', 'Wiraswasta', 'Pedagang', 'Petani', '-', 'Petani', '-',
                                   'Swasta', 'IRT', 'Tani', '-', 'WIRASWASTA', '-', 'WIRASWASTA']
nilai_pendidikan_yang_akan_diisi = ['SMA', 'SD', 'SMA', 'SD', 'SD', 'S1 ALIYAH', 'S2', 'SMA', 'SMA', 'SD', 'SD', 'SD', '-', 'SLTA', 'SLTA',
                                    'SLTP', 'SD', 'SLTP', 'SD', 'SLTP']

# Menggunakan metode at atau loc untuk setiap kolom dan indeks
for indeks, nama, pekerjaan, pendidikan in zip(indeks_yang_akan_diisi, nilai_nama_yang_akan_diisi, nilai_pekerjaan_yang_akan_diisi, nilai_pendidikan_yang_akan_diisi):
    Data_Sidorejo.loc[indeks, 'Nama'] = nama
    Data_Sidorejo.loc[indeks, 'Pekerjaan'] = pekerjaan
    Data_Sidorejo.loc[indeks, 'Pendidikan'] = pendidikan
# Out:
# <ipython-input-1336-1fff61da9fb3>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Data_Sidorejo.loc[indeks, 'Nama'] = nama
# <ipython-input-1336-1fff61da9fb3>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Data_Sidorejo.loc[indeks, 'Pekerjaan'] = pekerjaan
# <ipython-input-1336-1fff61da9fb3>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Data_Sidorejo.loc[indeks, 'Pendidikan'] = pendidikan

# %%
Data_Sidorejo.shape
# Out:
# (130, 4)

# %%
Data_Sidorejo
# Out:
#                          Nama              Pekerjaan          Pendidikan  \
# 0                MOCH ZARKASI              PENSIUNAN                   -
# 1               MUH KHOIRUDIN                   GURU                 S2
# 2                HADI SAPUTRO             WIRASWASTA                 SMA
# 3          ALMARHUM H.SADIMIN                      -                   -
# 4            ALMARHUM PURNOMO                      -                   -
# 5               SLAMET RIYADI          TIDAK BEKERJA                 SMP
# 6          HERY CAHYO SUSANTO             WIRASWASTA                 SMA
# 7           MUHADI (ALMARHUM)                    NaN                 NaN
# 8                       DAWAM              PENSIUNAN                 SMA
# 9                     KUNCORO                 PETANI                 SMA
# 10                    DAROINI                 PETANI                 SMA
# 11                 FATKURROJI         PETANI/PEKEBUN                 SMA
# ...

# %% [markdown]
# ## DUSUN JASEM - AMAN

# %% [markdown]
# ### RT01 - AMAN

# %%
JasemRT01 = pd.read_excel('ProyekDesa_Sedah/RekapSurveySensusDesaSedah/K22_JASEM/RekapSurveySensus_K22.xlsx', sheet_name='RT 1')
JasemRT01 =  JasemRT01.iloc[2:]
JasemRT01.head(1)
# Out:
#   Unnamed: 0  Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5
# 2    Suyatno  Buruh Tani    2 Motor        SMP     1 Anak     Kuning

# %%
JasemRT01.columns = ['Nama', 'Pekerjaan', 'Aset', 'Pendidikan', 'Jumlah Tanggungan', 'Kategori']

# %%
JasemRT01.head(36)
# AMAN
# Out:
#                       Nama              Pekerjaan                 Aset  \
# 2                  Suyatno             Buruh Tani              2 Motor
# 3              Abdurrohman                    NaN                  NaN
# 4              Sri Mulyati                   Guru  3 Motor dan 1 Mobil
# 5            Yoyok Susanto                 Swasta  3 Motor dan 1 Mobil
# 6             Siti Mariyam             Wiraswasta              2 Motor
# 7            Budi Prasetyo                    NaN                  NaN
# 8             Siti Fatonah       Ibu Rumah Tangga              1 Motor
# 9             Khabib Soleh                 Petani              2 Motor
# 10          Arif Kurniawan         Guru/Pengusaha  6 Motor dan 9 Mobil
# 11       Fatimatul Qoyimah                    NaN              1 Motor
# 12           Syaiful Bahri          Kuli Bangunan              2 Motor
# 13         Muflih Nur Huda                 Swasta              1 Motor
# ...

# %%
JasemRT01.shape
# Out:
# (36, 6)

# %% [markdown]
# ### RT02 - AMAN

# %%
JasemRT02 = pd.read_excel('ProyekDesa_Sedah/RekapSurveySensusDesaSedah/K22_JASEM/RekapSurveySensus_K22.xlsx', sheet_name='RT 2')
JasemRT02 =  JasemRT02.iloc[2:]
JasemRT02.head(1)
# Out:
#   Unnamed: 0  Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5
# 2    Sutarto  Wiraswasta    1 Motor       SLTP     2 Anak      Merah

# %%
JasemRT02.columns = ['Nama', 'Pekerjaan', 'Aset', 'Pendidikan', 'Jumlah Tanggungan', 'Kategori']

# %%
JasemRT02.head(47)
# AMAN
# Out:
#                    Nama              Pekerjaan                 Aset  \
# 2               Sutarto             Wiraswasta              1 Motor
# 3               Mujiono             Buruh Tani              4 Motor
# 4             H. Ma'ruf          Pensiunan KUA              1 Motor
# 5           A. Mufaizin                 Petani              1 Motor
# 6               Jukenti                    TKW              2 Motor
# 7                  Heri        Operator Genset              1 Motor
# 8          Agung Wiyono             Sopir Truk              3 Motor
# 9        Sastro Tunggak          Tidak Bekerja              2 Motor
# 10             Andriana                 Petani              2 Motor
# 11               Kantun                 Petani              2 Motor
# 12        Siti Masroqah       Ibu Rumah Tangga  1 Motor dan 1 Mobil
# 13    Muhibbudin Fathun                    SPV              2 Motor
# 14                 Wiji                 Petani              2 Motor
# ...

# %%
JasemRT02.shape
# Out:
# (47, 6)

# %% [markdown]
# ### RT03 - AMAN

# %%
JasemRT03 = pd.read_excel('ProyekDesa_Sedah/RekapSurveySensusDesaSedah/K22_JASEM/RekapSurveySensus_K22.xlsx', sheet_name='RT 3')
JasemRT03 =  JasemRT03.iloc[2:]
JasemRT03.head(1)
# Out:
#               Unnamed: 0  Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 2  Hendik Franky Ariasta  Wiraswasta    2 Motor       SLTP     2 Anak
#
#   Unnamed: 5
# 2     Kuning

# %%
JasemRT03.columns = ['Nama', 'Pekerjaan', 'Aset', 'Pendidikan', 'Jumlah Tanggungan', 'Kategori']

# %%
JasemRT03.head(45)
#  AMAN
# Out:
#                             Nama              Pekerjaan  \
# 2          Hendik Franky Ariasta             Wiraswasta
# 3                       Sutikno              Buruh Tani
# 4                      Agus Sait        Karyawan Swasta
# 5            Rizal Imanta Wijaya        Karyawan Swasta
# 6                Andik Wijanarko                    PNS
# 7                      Dedi Wiis                  POLRI
# 8                       Sugiyono        Tukang Bangunan
# 9                         Chudri                   TKI
# 10                       Suwandi                 Petani
# 11  Surya Anggi Romadhon Sobirin                 Petani
# 12                       Sukardi                 Petani
# 13                 Windu Guntari                   Guru
# 14             Hari Budi Santoso                  POLRI
# 15                       Supiyon         Perangkat Desa
# 16      Hening Anggraito Nugroho                  Supir
# 17                     Khamsanah             Buruh Tani
# ...

# %%
JasemRT03.shape
# Out:
# (45, 6)

# %% [markdown]
# ### MERGE RT 1 2 3

# %%
Data_Jasem = pd.merge(JasemRT01, JasemRT02, on=['Nama', 'Pekerjaan', 'Aset', 'Pendidikan', 'Jumlah Tanggungan',
       'Kategori'], how='outer')
Data_Jasem = pd.merge(Data_Jasem, JasemRT03, on=['Nama', 'Pekerjaan', 'Aset', 'Pendidikan', 'Jumlah Tanggungan',
       'Kategori'], how='outer')

# %%
Data_Jasem.columns
# Out:
# Index(['Nama', 'Pekerjaan', 'Aset', 'Pendidikan', 'Jumlah Tanggungan',
#        'Kategori'],
#       dtype='object')

# %%
# Menyimpan DataFrame ke dalam file Excel
nama_file_excel = 'data_penduduk_dusun_jasem.xlsx'
Data_Jasem.to_excel(nama_file_excel, index=False)

# %%
Data_Jasem = Data_Jasem[['Nama', 'Pekerjaan', 'Pendidikan', 'Kategori']]

# %%
LabelKategori = {'Hijau': 'SEJAHTERA', 'Kuning': 'MENENGAH', 'Merah': 'PRASEJAHTERA', 'Kunimg': 'MENENGAH'}
Data_Jasem['Kategori'] = Data_Jasem['Kategori'].replace(LabelKategori)
# Out:
# <ipython-input-1355-b85dee55a0fb>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Data_Jasem['Kategori'] = Data_Jasem['Kategori'].replace(LabelKategori)

# %%
Data_Jasem['Kategori'].value_counts()
# Out:
# SEJAHTERA       57
# MENENGAH        38
# PRASEJAHTERA    33
# Name: Kategori, dtype: int64

# %%
Data_Jasem
# Out:
#                              Nama              Pekerjaan Pendidikan  \
# 0                         Suyatno             Buruh Tani        SMP
# 1                     Abdurrohman                    NaN        NaN
# 2                     Sri Mulyati                   Guru         S1
# 3                   Yoyok Susanto                 Swasta        SMA
# 4                    Siti Mariyam             Wiraswasta        SMP
# 5                   Budi Prasetyo                    NaN        NaN
# 6                    Siti Fatonah       Ibu Rumah Tangga        SMP
# 7                    Khabib Soleh                 Petani         SD
# 8                  Arif Kurniawan         Guru/Pengusaha         S1
# 9               Fatimatul Qoyimah                    NaN         SD
# 10                  Syaiful Bahri          Kuli Bangunan        SMP
# 11                Muflih Nur Huda                 Swasta        SMA
# 12                          Harni              Serabutan         SD
# ...

# %% [markdown]
# ### TOTAL DATA

# %%
Data_Jasem.shape
# Out:
# (128, 4)

# %% [markdown]
# ## DUSUN GUNDI - AMAN

# %% [markdown]
# ### RT01

# %%
GundiRT01 = pd.read_excel('ProyekDesa_Sedah/RekapSurveySensusDesaSedah/K23_GUNDI/K23.xlsx', sheet_name='RT 1')
GundiRT01 =  GundiRT01.iloc[3:]
GundiRT01.head(1)
# Out:
#     No               Nama   Pekerjaan           Aset Pendidikan Terakhir  \
# 3  2.0  Muhamad Badarudin  Wiraswasta  Rumah tinggal                 SMA
#
#   Dusun Status Sosial
# 3   NaN      MENENGAH

# %%
GundiRT01.columns = ['No', 'Nama', 'Pekerjaan', 'Aset', 'Pendidikan', 'Dusun', 'Kategori']

# %%
GundiRT01 = GundiRT01[['No', 'Nama', 'Pekerjaan', 'Aset', 'Pendidikan', 'Kategori']]

# %%
GundiRT01 = GundiRT01.dropna(axis=0, how='all')

# %%
GundiRT01.head(187)
# Out:
#        No                         Nama           Pekerjaan  \
# 3     2.0            Muhamad Badarudin          Wiraswasta
# 4     NaN                    Jamilatun          Wiraswasta
# 6     3.0                       Suyati    Ibu Rumah Tangga
# 7     NaN                    Misgianto          Wiraswasta
# 9     4.0                      Sutarmi    Ibu Rumah Tangga
# 10    NaN                      Mujiono          Buruh Tani
# 12    5.0                     Munjiyah    Ibu Rumah Tangga
# 13    NaN                      Istipah    Ibu Rumah Tangga
# 15    6.0                       Katemi             Pekebun
# 16    NaN        Ramanda Perdana Putra                 NaN
# 18    7.0                      Subakit              Petani
# 19    NaN                  Dito Ananta                 NaN
# 21    8.0               Siti Munawaroh    Ibu Rumah Tangga
# 22    NaN    Felisha Nareswari Danarum              Swasta
# 24    9.0                       Darmi        Tidak Bekerja
# ...

# %%
GundiRT01.shape
# Out:
# (143, 6)

# %% [markdown]
# ### RT02

# %%
GundiRT02 = pd.read_excel('ProyekDesa_Sedah/RekapSurveySensusDesaSedah/K23_GUNDI/K23.xlsx', sheet_name='RT 2')
GundiRT02 =  GundiRT02.iloc[3:]
GundiRT02.head(1)
# Out:
#    Unnamed: 0    NAMA       PEKERJAAN                      ASET  \
# 3         2.0  MISWAN  BURUH BANGUNAN  RUMAH TINGGAL, KENDARAAN
#
#   PENDIDIKAN TERAKHR STATUS SOSIAL
# 3               SLTA      MENENGAH

# %%
GundiRT02.columns = ['No', 'Nama', 'Pekerjaan', 'Aset', 'Pendidikan', 'Kategori']

# %%
GundiRT02 = GundiRT02.dropna(axis=0, how='all')

# %%
GundiRT02
# Out:
#        No                                   Nama            Pekerjaan  \
# 3     2.0                                 MISWAN       BURUH BANGUNAN
# 4     NaN                     SUCI WASPANINGTYAS     IBU RUMAH TANGGA
# 5     NaN   SARISA ANGGRAINI PUTRI WASPANINGTYAS              PELAJAR
# 7     3.0                             SARINGATUN        TIDAK BEKERJA
# 9     4.0                          JOKO SUPRAPTO           BURUH TANI
# 10    NaN                                SUMINEM     IBU RUMAH TANGGA
# 11    NaN                           BAGUS ARGANA              PELAJAR
# 12    NaN                      OQI PRIYAN MAHESA              PELAJAR
# 14    5.0                                SUMARNO           WIRASWASTA
# 15    NaN                        LENNY KRISTIANA     IBU RUMAH TANGGA
# 16    NaN                    HELMY AUFA MUBARAK               PELAJAR
# 18    6.0                        MUHAMMAD ARIFIN      KARYAWAN SWASTA
# ...

# %%
GundiRT02.shape
# Out:
# (155, 6)

# %% [markdown]
# ### RT03

# %%
GundiRT03 = pd.read_excel('ProyekDesa_Sedah/RekapSurveySensusDesaSedah/K23_GUNDI/K23.xlsx', sheet_name='RT 3')
GundiRT03 =  GundiRT03.iloc[3:]
GundiRT03.head(1)
# Out:
#     No      Nama Pekerjaan           Aset Pendidikan Terakhir  Dusun  \
# 3  2.0  Munjiyat         -  Rumah Tinggal                  SD  Gundi
#
#   Status Sosial
# 3  PRASEJAHTERA

# %%
GundiRT03.columns = ['No', 'Nama', 'Pekerjaan', 'Aset', 'Pendidikan', 'Dusun',
       'Kategori']

# %%
GundiRT03 = GundiRT03.dropna(axis=0, how='all')

# %%
GundiRT03.head(185)
# Out:
#        No                           Nama  \
# 3     2.0                       Munjiyat
# 4     NaN                        Alfiyah
# 6     3.0              Muhyidin kholisna
# 7     NaN                   Ana Yulianti
# 8     NaN          Muhamad Razan akhsani
# 9     NaN         Muhamad Ansor Ramadani
# 11    4.0                       Irchamni
# 12    NaN                       Sunarsih
# 14    5.0        Nurul Hidayatul Mardiah
# 16    6.0                 Imam Syafa'at
# 17    NaN                  Siti Indanah
# 19    7.0                    Imam Maliki
# 20    NaN                  Binti Hidayah
# 21    NaN        Aufa finnida muzayyaroh
# 23    8.0                    Moh. Hanafi
# 24    NaN                Chusnun Ni'aman
# 25    NaN         Muhammad hasnin adyani
# 26    NaN                Husnaya Amalina
# 28    9.0                         Fanani
# 29    NaN                  Atik asfihani
# 31   10.0                 Syaful Ikhwan
# 32    NaN              Lailatul Maimunah
# ...

# %% [markdown]
# ### MERGE RT 1 2 3

# %%
GundiRT01.columns
# Out:
# Index(['No', 'Nama', 'Pekerjaan', 'Aset', 'Pendidikan', 'Kategori'], dtype='object')

# %%
GundiRT02.columns
# Out:
# Index(['No', 'Nama', 'Pekerjaan', 'Aset', 'Pendidikan', 'Kategori'], dtype='object')

# %%
GundiRT03.columns
# Out:
# Index(['No', 'Nama', 'Pekerjaan', 'Aset', 'Pendidikan', 'Dusun', 'Kategori'], dtype='object')

# %%
Data_Gundi = pd.merge(GundiRT01, GundiRT02, on=['No', 'Nama', 'Pekerjaan', 'Aset', 'Pendidikan', 'Kategori'], how='outer')
Data_Gundi = pd.merge(Data_Gundi, GundiRT03, on=['No', 'Nama', 'Pekerjaan', 'Aset', 'Pendidikan', 'Kategori'], how='outer')

# %%
LabelKategori = {'SEJAHTERA ': 'SEJAHTERA'}
Data_Gundi['Kategori'] = Data_Gundi['Kategori'].replace(LabelKategori)

# %%
Data_Gundi = Data_Gundi[['Nama', 'Pekerjaan', 'Pendidikan', 'Kategori']]

# %%
Data_Gundi['Kategori'].value_counts()
# Out:
# SEJAHTERA       193
# MENENGAH        156
# PRASEJAHTERA     79
# Name: Kategori, dtype: int64

# %% [markdown]
# ### FULL DATA

# %%
Gundi = pd.read_excel('ProyekDesa_Sedah/RekapSurveySensusDesaSedah/K23_GUNDI/K23.xlsx', sheet_name='FULL DATA ')
Gundi =  Gundi.iloc[3:]
Gundi.head(1)
# Out:
#     kk               Name         Job         Assets Teritary Education  \
# 3  2.0  Muhamad Badarudin  Wiraswasta  Rumah tinggal                SMA
#
#   Unnamed: 5
# 3   MENENGAH

# %%
Gundi
# Out:
#         kk                      Name  \
# 3      2.0         Muhamad Badarudin
# 4      NaN                       NaN
# 5      NaN                       NaN
# 6      3.0                    Suyati
# 7      NaN                       NaN
# 8      NaN                       NaN
# 9      4.0                   Sutarmi
# 10     NaN                       NaN
# 11     NaN                       NaN
# 12     5.0                  Munjiyah
# 13     NaN                       NaN
# 14     NaN                       NaN
# 15     6.0                    Katemi
# 16     NaN                       NaN
# 17     NaN                       NaN
# 18     7.0                   Subakit
# 19     NaN                       NaN
# 20     NaN                       NaN
# 21     8.0            Siti Munawaroh
# 22     NaN                       NaN
# 23     NaN                       NaN
# 24     9.0                    Darmi
# 25     NaN                       NaN
# 26    10.0                   Maryuni
# ...

# %%
Gundi = Gundi.dropna(axis=0, how='all')

# %%
Gundi.columns = ['KK', 'Nama', 'Pekerjaan', 'Aset', 'Pendidikan', 'Kategori']

# %%
# Menyimpan DataFrame ke dalam file Excel
nama_file_excel = 'data_penduduk_dusun_gundi.xlsx'
Gundi.to_excel(nama_file_excel, index=False)

# %%
Gundi = Gundi[['Nama', 'Pekerjaan', 'Pendidikan', 'Kategori']]

# %%
Gundi
# Out:
#                          Nama                                     Pekerjaan  \
# 3           Muhamad Badarudin                                    Wiraswasta
# 6                      Suyati                              Ibu Rumah Tangga
# 9                     Sutarmi                              Ibu Rumah Tangga
# 12                   Munjiyah                              Ibu Rumah Tangga
# 15                     Katemi                                       Pekebun
# 18                    Subakit                                        Petani
# 21             Siti Munawaroh                              Ibu Rumah Tangga
# 24                     Darmi                                  Tidak Bekerja
# 26                    Maryuni                              Ibu Rumah tangga
# 28                   Sunarsih                              Ibu Rumah tangga
# 30                   Masjudi                                    Wirasuwasta
# ...

# %% [markdown]
# ### TOTAL ITEM

# %%
Data_Gundi.shape
# Out:
# (428, 4)

# %% [markdown]
# ## MERGE DATA DUSUN

# %%
Data_KrajanSidorejo = pd.merge(Data_Krajan, Data_Sidorejo, on=['Nama', 'Pekerjaan', 'Pendidikan', 'Kategori'], how='outer')
Data_KrajanSidorejo.head()
# Out:
#                 Nama            Pekerjaan Pendidikan  Kategori
# 0          ALI IMRON               TUKANG        SMA  MENENGAH
# 1            SUMANTO           BURUH TANI        SMP  MENENGAH
# 2  ARIF WAHYU WIDODO  PEGAWAI RUMAH SAKIT        SMA  MENENGAH
# 3            KADIMUN               TUKANG        SMA  MENENGAH
# 4              SAKRI               PETANI         SD  MENENGAH

# %%
Data_KrajanSidorejoJasem = pd.merge(Data_KrajanSidorejo, Data_Jasem, on=['Nama', 'Pekerjaan', 'Pendidikan', 'Kategori'], how='outer')
Data_KrajanSidorejoJasem.head()
# Out:
#                 Nama            Pekerjaan Pendidikan  Kategori
# 0          ALI IMRON               TUKANG        SMA  MENENGAH
# 1            SUMANTO           BURUH TANI        SMP  MENENGAH
# 2  ARIF WAHYU WIDODO  PEGAWAI RUMAH SAKIT        SMA  MENENGAH
# 3            KADIMUN               TUKANG        SMA  MENENGAH
# 4              SAKRI               PETANI         SD  MENENGAH

# %%
Data_Sedah = pd.merge(Data_KrajanSidorejo, Data_Gundi, on=['Nama', 'Pekerjaan', 'Pendidikan', 'Kategori'], how='outer')
Data_Sedah.head()
# Out:
#                 Nama            Pekerjaan Pendidikan  Kategori
# 0          ALI IMRON               TUKANG        SMA  MENENGAH
# 1            SUMANTO           BURUH TANI        SMP  MENENGAH
# 2  ARIF WAHYU WIDODO  PEGAWAI RUMAH SAKIT        SMA  MENENGAH
# 3            KADIMUN               TUKANG        SMA  MENENGAH
# 4              SAKRI               PETANI         SD  MENENGAH

# %%
# Menyimpan DataFrame ke dalam file Excel
nama_file_excel = 'data_penduduk_desa_sedah.xlsx'
Data_Sedah.to_excel(nama_file_excel, index=False)

# %%
Data_Sedah.shape
# Out:
# (673, 4)

# %%
# Membuat figure dan axes
fig, ax = plt.subplots()

# Mengatur warna untuk setiap kategori
warna_kategori = ['yellow', 'green', 'red']

# Membuat countplot menggunakan seaborn dan mengatur warna secara manual
sns.countplot( ax=ax, x='Kategori',
              data=Data_Sedah,
              palette=warna_kategori)

# Menambahkan judul
ax.set_title('Data Penduduk Desa Sedah')

# Menambahkan label persentase pada setiap bar
total_data = len(Data_Sedah['Kategori'])
for p in ax.patches:
    percentage = '{:.1f}%'.format(100 * p.get_height() / total_data)
    ax.annotate(percentage, (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', xytext=(0, 10), textcoords='offset points')

# Menampilkan plot
plt.show()
# Out:
# <ipython-input-1394-82bc6a82bbb2>:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot( ax=ax, x='Kategori',

# %%
# Membuat figure dan axes
fig, ax = plt.subplots()

# Mengatur urutan label kategori
urutan_kategori = ['SEJAHTERA', 'MENENGAH', 'PRASEJAHTERA']

# Mengatur warna untuk setiap kategori
warna_kategori = ['yellow', 'green', 'red']

# Membuat countplot menggunakan seaborn dan mengatur warna serta urutan secara manual
sns.countplot(ax=ax, x='Kategori', data=Data_Sedah, palette=warna_kategori, order=urutan_kategori)

# Menambahkan judul
ax.set_title('Data Penduduk Desa Sedah')

# Menambahkan label persentase pada setiap bar
total_data = len(Data_Sedah['Kategori'])
for p, color in zip(ax.patches, warna_kategori):
    percentage = '{:.1f}%'.format(100 * p.get_height() / total_data)
    ax.annotate(percentage, (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', xytext=(0, 10), textcoords='offset points',
                color=color, weight='bold', size=12)  # Menambahkan warna dan mengatur properti teks

# Menampilkan plot
plt.show()
# Out:
# <ipython-input-1395-25472b0c0376>:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(ax=ax, x='Kategori', data=Data_Sedah, palette=warna_kategori, order=urutan_kategori)

# %%
# Membuat figure dan axes
fig, ax = plt.subplots()

# Mengatur urutan label kategori
urutan_kategori = ['SEJAHTERA', 'MENENGAH', 'PRASEJAHTERA']

# Mengatur warna untuk setiap kategori
warna_kategori = ['yellow', 'green', 'red']

# Membuat countplot menggunakan seaborn dan mengatur warna serta urutan secara manual
sns.countplot(ax=ax, x='Kategori',
              data=Data_Sedah,
              palette=warna_kategori, order=urutan_kategori)

# Menambahkan judul
ax.set_title('Status Sosial Penduduk Desa Sedah')
# Mengatur label sumbu x dan y
ax.set_xlabel('Status Sosial')
ax.set_ylabel('Jumlah')

# Menambahkan label persentase pada setiap bar
total_data = len(Data_Sedah['Kategori'])
for p, color in zip(ax.patches, warna_kategori):
    percentage = '{:.1f}%'.format(100 * p.get_height() / total_data)
    ax.annotate(percentage, (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', xytext=(0, 10), textcoords='offset points',
                color='black', weight='bold', size=12)  # Mengatur warna teks menjadi hitam

# Menampilkan plot
plt.show()
# Out:
# <ipython-input-1396-90cddf248987>:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(ax=ax, x='Kategori',

# %% [markdown]
# ## VISUALISASI DATA STATUS SOSIAL DESA SEDAH

# %%
# Membuat figure dan axes
fig, ax = plt.subplots()

# Mengatur urutan label kategori
urutan_kategori = ['SEJAHTERA', 'MENENGAH', 'PRASEJAHTERA']

# Mengatur warna untuk setiap kategori
warna_kategori = ['yellow', 'green', 'red']

# Membuat countplot menggunakan seaborn dan mengatur warna serta urutan secara manual
sns.countplot(ax=ax, x='Kategori',
              data=Data_Sedah,
              palette=warna_kategori, order=urutan_kategori)

# Menambahkan judul
ax.set_title('Status Sosial Penduduk Desa Sedah')
# Mengatur label sumbu x dan y
ax.set_xlabel('Status Sosial')
ax.set_ylabel('Jumlah')

# Menambahkan label persentase pada setiap bar
total_data = len(Data_Sedah['Kategori'])
for p, color in zip(ax.patches, warna_kategori):
    percentage = '{:.1f}%'.format(100 * p.get_height() / total_data)
    ax.annotate(percentage, (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='bottom', xytext=(0, 1), textcoords='offset points',
                color='black', weight='bold', size=11)  # Mengatur posisi teks

# Menampilkan plot
plt.show()
# Out:
# <ipython-input-1397-b375798aab24>:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(ax=ax, x='Kategori',

# %%
# Membuat figure dan axes
fig, ax = plt.subplots()

# Mengatur urutan label kategori
urutan_kategori = ['SEJAHTERA', 'MENENGAH', 'PRASEJAHTERA']

# Mengatur warna untuk setiap kategori
warna_kategori = ['yellow', 'green', 'red']

# Membuat countplot menggunakan seaborn dan mengatur warna serta urutan secara manual
sns.countplot(ax=ax, x='Kategori',
              data=Data_Krajan,
              palette=warna_kategori, order=urutan_kategori)

# Menambahkan judul
ax.set_title('Status Sosial Penduduk Dusun Krajan')
# Mengatur label sumbu x dan y
ax.set_xlabel('Status Sosial')
ax.set_ylabel('Jumlah')

# Menambahkan label persentase pada setiap bar
total_data = len(Data_Krajan['Kategori'])
for p, color in zip(ax.patches, warna_kategori):
    percentage = '{:.1f}%'.format(100 * p.get_height() / total_data)
    ax.annotate(percentage, (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='bottom', xytext=(0, 1), textcoords='offset points',
                color='black', weight='bold', size=11)  # Mengatur posisi teks

# Menampilkan plot
plt.show()
# Out:
# <ipython-input-1398-7f48e6e60e3b>:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(ax=ax, x='Kategori',

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Membuat figure dan axes
fig, ax = plt.subplots()

# Mengatur urutan label kategori
urutan_kategori = ['SEJAHTERA', 'MENENGAH', 'PRASEJAHTERA']

# Mengatur warna untuk setiap kategori
warna_kategori = ['yellow', 'green', 'red']

# Membuat countplot menggunakan seaborn dan mengatur warna serta urutan secara manual
sns.countplot(ax=ax, x='Kategori',
              data=Data_Krajan,
              palette=warna_kategori, order=urutan_kategori)

# Menambahkan judul
ax.set_title('Status Sosial Penduduk Dusun Krajan')
# Mengatur label sumbu x dan y
ax.set_xlabel('Status Sosial')
ax.set_ylabel('Jumlah')

# Menambahkan label persentase pada setiap bar
total_data = len(Data_Krajan['Kategori'])
for p, color in zip(ax.patches, warna_kategori):
    percentage = '{:.1f}%'.format(100 * p.get_height() / total_data)
    jumlah = int(p.get_height())  # Menambahkan label jumlah masing-masing kategori
    ax.annotate(f'{percentage} ({jumlah})', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='bottom', xytext=(0, 1), textcoords='offset points',
                color='black', weight='bold', size=10)  # Mengatur posisi teks

# Menampilkan plot
plt.show()
# Out:
# <ipython-input-1399-f13b10740aff>:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(ax=ax, x='Kategori',

# %%
# Membuat figure dan axes
fig, ax = plt.subplots()

# Mengatur urutan label kategori
urutan_kategori = ['SEJAHTERA', 'MENENGAH', 'PRASEJAHTERA']

# Mengatur warna untuk setiap kategori
warna_kategori = ['yellow', 'green', 'red']

# Membuat countplot menggunakan seaborn dan mengatur warna serta urutan secara manual
sns.countplot(ax=ax, x='Kategori',
              data=Data_Sidorejo,
              palette=warna_kategori, order=urutan_kategori)

# Menambahkan judul
ax.set_title('Status Sosial Penduduk Dusun Sidorejo')
# Mengatur label sumbu x dan y
ax.set_xlabel('Status Sosial')
ax.set_ylabel('Jumlah')

# Menambahkan label persentase pada setiap bar
total_data = len(Data_Sidorejo['Kategori'])
for p, color in zip(ax.patches, warna_kategori):
    percentage = '{:.1f}%'.format(100 * p.get_height() / total_data)
    jumlah = int(p.get_height())  # Menambahkan label jumlah masing-masing kategori
    ax.annotate(f'{percentage} ({jumlah})', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='bottom', xytext=(0, 1), textcoords='offset points',
                color='black', weight='bold', size=10)  # Mengatur posisi teks

# Menampilkan plot
plt.show()
# Out:
# <ipython-input-1400-89c074592116>:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(ax=ax, x='Kategori',

# %%
# Membuat figure dan axes
fig, ax = plt.subplots()

# Mengatur urutan label kategori
urutan_kategori = ['SEJAHTERA', 'MENENGAH', 'PRASEJAHTERA']

# Mengatur warna untuk setiap kategori
warna_kategori = ['yellow', 'green', 'red']

# Membuat countplot menggunakan seaborn dan mengatur warna serta urutan secara manual
sns.countplot(ax=ax, x='Kategori',
              data=Data_Jasem,
              palette=warna_kategori, order=urutan_kategori)

# Menambahkan judul
ax.set_title('Status Sosial Penduduk Dusun Jasem')
# Mengatur label sumbu x dan y
ax.set_xlabel('Status Sosial')
ax.set_ylabel('Jumlah')

# Menambahkan label persentase pada setiap bar
total_data = len(Data_Jasem['Kategori'])
for p, color in zip(ax.patches, warna_kategori):
    percentage = '{:.1f}%'.format(100 * p.get_height() / total_data)
    jumlah = int(p.get_height())  # Menambahkan label jumlah masing-masing kategori
    ax.annotate(f'{percentage} ({jumlah})', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='bottom', xytext=(0, 1), textcoords='offset points',
                color='black', weight='bold', size=10)  # Mengatur posisi teks

# Menampilkan plot
plt.show()
# Out:
# <ipython-input-1401-929f8aa7727d>:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(ax=ax, x='Kategori',

# %%
# Membuat figure dan axes
fig, ax = plt.subplots()

# Mengatur urutan label kategori
urutan_kategori = ['SEJAHTERA', 'MENENGAH', 'PRASEJAHTERA']

# Mengatur warna untuk setiap kategori
warna_kategori = ['yellow', 'green', 'red']

# Membuat countplot menggunakan seaborn dan mengatur warna serta urutan secara manual
sns.countplot(ax=ax, x='Kategori',
              data=Gundi,
              palette=warna_kategori, order=urutan_kategori)

# Menambahkan judul
ax.set_title('Status Sosial Penduduk Dusun Gundi')
# Mengatur label sumbu x dan y
ax.set_xlabel('Status Sosial')
ax.set_ylabel('Jumlah')

# Menambahkan label persentase pada setiap bar
total_data = len(Gundi['Kategori'])
for p, color in zip(ax.patches, warna_kategori):
    percentage = '{:.1f}%'.format(100 * p.get_height() / total_data)
    jumlah = int(p.get_height())  # Menambahkan label jumlah masing-masing kategori
    ax.annotate(f'{percentage} ({jumlah})', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='bottom', xytext=(0, 1), textcoords='offset points',
                color='black', weight='bold', size=10)  # Mengatur posisi teks

# Menampilkan plot
plt.show()
# Out:
# <ipython-input-1402-9d46e4e240e2>:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(ax=ax, x='Kategori',

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Mengatur ukuran figure secara global
plt.figure(figsize=(12, 6))

# Subplot pertama
plt.subplot(1, 2, 1)  # 1 baris, 2 kolom, subplot pertama
urutan_kategori = ['SEJAHTERA', 'MENENGAH', 'PRASEJAHTERA']
warna_kategori = ['yellow', 'green', 'red']
sns.countplot(x='Kategori', data=Data_Krajan, palette=warna_kategori, order=urutan_kategori)
plt.title('Status Sosial Penduduk Dusun Krajan')
plt.xlabel('Status Sosial')
plt.ylabel('Jumlah')
total_data = len(Data_Krajan['Kategori'])
for p, color in zip(plt.gca().patches, warna_kategori):
    percentage = '{:.1f}%'.format(100 * p.get_height() / total_data)
    plt.gca().annotate(percentage, (p.get_x() + p.get_width() / 2., p.get_height()),
                       ha='center', va='bottom', xytext=(0, 1), textcoords='offset points',
                       color='black', weight='bold', size=11)

# Subplot kedua
plt.subplot(1, 2, 2)  # 1 baris, 2 kolom, subplot kedua
urutan_kategori = ['SEJAHTERA', 'MENENGAH', 'PRASEJAHTERA']
warna_kategori = ['yellow', 'green', 'red']
sns.countplot(x='Kategori', data=Data_Sidorejo, palette=warna_kategori, order=urutan_kategori)
plt.title('Status Sosial Penduduk Dusun Sidorejo')
plt.xlabel('Status Sosial')
plt.ylabel('Jumlah')
total_data = len(Data_Sidorejo['Kategori'])
for p, color in zip(plt.gca().patches, warna_kategori):
    percentage = '{:.1f}%'.format(100 * p.get_height() / total_data)
    plt.gca().annotate(percentage, (p.get_x() + p.get_width() / 2., p.get_height()),
                       ha='center', va='bottom', xytext=(0, 1), textcoords='offset points',
                       color='black', weight='bold', size=11)

# Menampilkan plot
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-1403-4a057e2ae5de>:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Kategori', data=Data_Krajan, palette=warna_kategori, order=urutan_kategori)
# <ipython-input-1403-4a057e2ae5de>:26: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Kategori', data=Data_Sidorejo, palette=warna_kategori, order=urutan_kategori)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Mengatur ukuran figure secara global
plt.figure(figsize=(18, 12))

# Subplot pertama
plt.subplot(2, 2, 1)  # 2 baris, 2 kolom, subplot pertama
urutan_kategori = ['SEJAHTERA', 'MENENGAH', 'PRASEJAHTERA']
warna_kategori = ['yellow', 'green', 'red']
sns.countplot(x='Kategori', data=Data_Krajan, palette=warna_kategori, order=urutan_kategori)
plt.title('Dusun Krajan')
plt.xlabel('Status Sosial')
plt.ylabel('Jumlah')
total_data = len(Data_Krajan['Kategori'])
for p, color in zip(plt.gca().patches, warna_kategori):
    percentage = '{:.1f}%'.format(100 * p.get_height() / total_data)
    plt.gca().annotate(percentage, (p.get_x() + p.get_width() / 2., p.get_height()),
                       ha='center', va='bottom', xytext=(0, 1), textcoords='offset points',
                       color='black', weight='bold', size=11)

# Subplot kedua
plt.subplot(2, 2, 2)  # 2 baris, 2 kolom, subplot kedua
sns.countplot(x='Kategori', data=Data_Sidorejo, palette=warna_kategori, order=urutan_kategori)
plt.title('Dusun Sidorejo')
plt.xlabel('Status Sosial')
plt.ylabel('Jumlah')
total_data = len(Data_Sidorejo['Kategori'])
for p, color in zip(plt.gca().patches, warna_kategori):
    percentage = '{:.1f}%'.format(100 * p.get_height() / total_data)
    plt.gca().annotate(percentage, (p.get_x() + p.get_width() / 2., p.get_height()),
                       ha='center', va='bottom', xytext=(0, 1), textcoords='offset points',
                       color='black', weight='bold', size=11)

# Subplot ketiga
plt.subplot(2, 2, 3)  # 2 baris, 2 kolom, subplot ketiga
sns.countplot(x='Kategori', data=Data_Jasem, palette=warna_kategori, order=urutan_kategori)
plt.title('Dusun Jasem')
plt.xlabel('Status Sosial')
plt.ylabel('Jumlah')
total_data = len(Data_Jasem['Kategori'])
for p, color in zip(plt.gca().patches, warna_kategori):
    percentage = '{:.1f}%'.format(100 * p.get_height() / total_data)
    plt.gca().annotate(percentage, (p.get_x() + p.get_width() / 2., p.get_height()),
                       ha='center', va='bottom', xytext=(0, 1), textcoords='offset points',
                       color='black', weight='bold', size=11)

# Subplot keempat
plt.subplot(2, 2, 4)  # 2 baris, 2 kolom, subplot keempat
sns.countplot(x='Kategori', data=Gundi, palette=warna_kategori, order=urutan_kategori)
plt.title('Dusun Gundi')
plt.xlabel('Status Sosial')
plt.ylabel('Jumlah')
total_data = len(Gundi['Kategori'])
for p, color in zip(plt.gca().patches, warna_kategori):
    percentage = '{:.1f}%'.format(100 * p.get_height() / total_data)
    plt.gca().annotate(percentage, (p.get_x() + p.get_width() / 2., p.get_height()),
                       ha='center', va='bottom', xytext=(0, 1), textcoords='offset points',
                       color='black', weight='bold', size=11)

# Menampilkan plot
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-1404-50844b195ee5>:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Kategori', data=Data_Krajan, palette=warna_kategori, order=urutan_kategori)
# <ipython-input-1404-50844b195ee5>:24: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Kategori', data=Data_Sidorejo, palette=warna_kategori, order=urutan_kategori)
# <ipython-input-1404-50844b195ee5>:37: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Kategori', data=Data_Jasem, palette=warna_kategori, order=urutan_kategori)
# ...
